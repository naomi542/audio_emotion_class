# %%
## Python
import os
import random
import sys
import warnings
warnings.filterwarnings('ignore')


## Package
import glob 
import keras
import IPython.display as ipd
import librosa

import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)


## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.utils import to_categorical

from keras.models import Model, Sequential
from keras import optimizers
from keras.layers import Input, Conv1D, Conv2D,BatchNormalization, MaxPooling1D,MaxPooling2D, LSTM, Dense, Activation, Layer,Reshape, Bidirectional, Softmax, Attention

# bidir, softmax, attn

from keras.utils import to_categorical
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model


## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm_notebook as tqdm

## TensorFlow
import tensorflow as tf
tf.test.is_gpu_available()

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# WARNING:tensorflow:From <ipython-input-1-e3563c142f09>:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive_prefix = '/content/gdrive/MyDrive/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### RAVDESS DATASET

# %%
# Data Directory
# Please edit according to your directory change.
Ravdess_path = drive_prefix + "SYDE 522 - Team Project/Code/data/"
dir_list = os.listdir(Ravdess_path)
dir_list.sort()
print (dir_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24', 'audio_speech_actors_01-24']

# %%
# Create DataFrame for Data intel
ravdess_db = pd.DataFrame(columns=['path','source','actor', 'gender', 'emotion','emotion_lb'])
count = 0

for i in dir_list:
    if i == "audio_speech_actors_01-24":
        continue
    file_list = os.listdir(Ravdess_path + i)
    for f in file_list:
        nm = f.split('.')[0].split('-')
        path = Ravdess_path + i + '/' + f
        src = int(nm[1])
        actor = int(nm[-1])
        emotion = int(nm[2])
        source = "Ravdess"

        if int(actor)%2 == 0:
            gender = "female"
        else:
            gender = "male"

        if nm[3] == '01':
            intensity = 0
        else:
            intensity = 1

        if nm[4] == '01':
            statement = 0
        else:
            statement = 1

        if nm[5] == '01':
            repeat = 0
        else:
            repeat = 1

        if emotion == 1:
            lb = "neutral"
        elif emotion == 2:
            lb = "calm"
        elif emotion == 3:
            lb = "happy"
        elif emotion == 4:
            lb = "sad"
        elif emotion == 5:
            lb = "angry"
        elif emotion == 6:
            lb = "fearful"
        elif emotion == 7:
            lb = "disgust"
        elif emotion == 8:
            lb = "surprised"
        else:
            lb = "none"

        ravdess_db.loc[count] = [path,source,actor, gender, emotion,lb]
        count += 1

# %%
ravdess_db.head()
# Out:
#                                                 path  ... emotion_lb
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 3  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
#
# [5 rows x 6 columns]

# %%
ravdess_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list.csv")

# %%
ravdess_db['split'] =  np.where((ravdess_db.actor ==23) | (ravdess_db.actor ==24), 'Test', 
                                (np.where((ravdess_db.actor ==21) | (ravdess_db.actor ==22),'Val','Train')))

# %%
ravdess_db['split'].value_counts()
# Out:
# Train    1200
# Test      120
# Val       120
# Name: split, dtype: int64

# %%
## DROP FEMALES
ravdess_db.drop(ravdess_db.index[ravdess_db['gender'] == 'male'], inplace = True)

# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'surprised'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'neutral'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'calm'], inplace = True)
ravdess_db.loc[ravdess_db.emotion_lb=='calm',['emotion','emotion_lb']]= 1,'neutral'

# %%
ravdess_db.emotion_lb.value_counts()
# Out:
# neutral      144
# fearful       96
# angry         96
# surprised     96
# disgust       96
# happy         96
# sad           96
# Name: emotion_lb, dtype: int64

# %%
dataset_db = ravdess_db.copy()

# %%
dataset_db.emotion_lb = dataset_db.gender+"_"+dataset_db.emotion_lb

# %%
dataset_db.index=range(len(dataset_db.index))

# %%
dataset_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list2.csv")

# %%
dataset_db.emotion_lb.value_counts()
dataset_db.sort_values(by=['path'], inplace=True)
dataset_db.head()
# Out:
#                                                  path  ...  split
# 9   /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 4   /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 5   /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 10  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 8   /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
#
# [5 rows x 7 columns]

# %%
dataset_db.index = range(len(dataset_db.index))

# %%
dataset_db.shape
# Out:
# (720, 7)

# %%
# ######## RUN THIS CELL FOR 2 CLASSES! :)
# # 2 class: Positive & Negative

# # Positive: Happy, Surprised
# # Negative: Angry, Fearful, Sad

# label2_list = []
# for i in range(len(dataset_db)):
#     # if dataset_db.emotion[i] == 2: # Calm
#     #     lb = "_positive"
#     if dataset_db.emotion[i] == 3: # Happy
#         lb = "_positive"
#     elif dataset_db.emotion[i] == 4: # Sad
#         lb = "_negative"
#     elif dataset_db.emotion[i] == 5: # Angry
#         lb = "_negative"
#     elif dataset_db.emotion[i] == 6: # Fearful
#         lb = "_negative"
#     elif dataset_db.emotion[i] == 7: # Disgust
#         lb = "_negative"
#     elif dataset_db.emotion[i] == 8: # Surprised
#         lb = "_positive"
#     else:
#         lb = "_error"
        
#     # Add gender to the label    
#     label2_list.append(dataset_db.gender[i] + lb)
    
# len(label2_list)

# dataset_db['label'] = label2_list
# dataset_db.head()
# print (dataset_db.label.value_counts().keys())

# %%
n_mfccaudio_duration = 3
sampling_rate = 22050*2
# input_length = sampling_rate * audio_duration # NameError: name 'audio_duration' is not defined
input_length = sampling_rate * n_mfccaudio_duration
n_mfcc = 12

# %%
data_sample= np.zeros(input_length)
MFCC = librosa.feature.mfcc(data_sample, sr=sampling_rate, n_mfcc=n_mfcc)

# %%
MFCC.shape
# (coefficients, windows)(?) - for 1 ____
# Out:
# (12, 259)

# %%
dataset_db.split.value_counts()
# Out:
# Train    600
# Test      60
# Val       60
# Name: split, dtype: int64

# %%
from tqdm import tqdm_notebook as tqdm

# %%
signal, sample_rate = librosa.load(dataset_db.path[0], res_type='kaiser_fast',sr=sampling_rate)
signal,index = librosa.effects.trim(signal,top_db = 25)
signal = scipy.signal.wiener(signal)

if len(signal) > input_length:
    signal = signal[0:input_length]
elif  input_length > len(signal):
    max_offset = input_length - len(signal)  
    signal = np.pad(signal, (0, max_offset), "constant")

# %%
signal = np.array(signal).reshape(-1,1)

# %%
signal.shape
# Out:
# (132300, 1)

# %%
# Cell w/ the loading bar, takes ~
audios= np.empty(shape=(dataset_db.shape[0],128, MFCC.shape[1], 1))

count=0
for i in tqdm(range(len(dataset_db))):
    signal, sample_rate = librosa.load(dataset_db.path[i], res_type='kaiser_fast',sr=sampling_rate)
    signal,index = librosa.effects.trim(signal,top_db = 25)
    signal = scipy.signal.wiener(signal)
    
    if len(signal) > input_length:
        signal = signal[0:input_length]
    elif  input_length > len(signal):
        max_offset = input_length - len(signal)  
        signal = np.pad(signal, (0, max_offset), "constant")

    melspec = librosa.feature.melspectrogram(signal, sr=sample_rate, n_mels=128,n_fft=2048,hop_length=512)   
    logspec = librosa.amplitude_to_db(melspec)
    logspec = np.expand_dims(logspec, axis=-1)
    audios[count,] = logspec 
    count+=1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=720.0), HTML(value='')))

# %%
audios.shape
# (, n_mels, , )
# Out:
# (720, 128, 259, 1)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'w') as hf:
    hf.create_dataset("Ravdess_audio_Mel_spec",  data=audios)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'r') as hf:
  audios = hf['Ravdess_audio_Mel_spec'][:]

# %%
librosa.display.specshow(audios[0].reshape(128,259))

# %%
x_train = audios[(dataset_db['split'] == 'Train')]

#### use this for all 12 classes
y_train = dataset_db.emotion_lb[(dataset_db['split'] == 'Train')]

#### use this for not all classes
# y_train = dataset_db.label[(dataset_db['split'] == 'Train')]

print(x_train.shape,y_train.shape)
# Out:
# (600, 128, 259, 1) (600,)

# %%
x_test = audios[(dataset_db['split'] == 'Val')]

#### use this for all 12 classes
y_test = dataset_db.emotion_lb[(dataset_db['split'] == 'Val')]

#### use this for not all classes
# y_test = dataset_db.label[(dataset_db['split'] == 'Val')]

print(x_test.shape,y_test.shape)
# Out:
# (60, 128, 259, 1) (60,)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))

# %%
x_traincnn = x_train
x_testcnn = x_test

# %%
x_traincnn.shape,x_testcnn.shape,y_train.shape,y_test.shape
# Out:
# ((600, 128, 259, 1), (60, 128, 259, 1), (600, 7), (60, 7))

# %%
# CNN I/P Config
num_classes = len(np.unique(np.argmax(y_train, 1)))
input_shape = x_traincnn.shape[1:]
learning_rate = 0.0001
decay = 1e-6
momentum = 0.9

#LSTM Configuration
num_lstm = 256

# %%
input_shape
# Out:
# (128, 259, 1)

# %%
# clear model to prevent layers appending constantly while troubleshooting
tf.keras.backend.clear_session()

model = Sequential(name='Audio_CNN_2D')

# LFLB1
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', data_format='channels_last',input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2), strides=(4,4)))
model.add(Dropout(0.2))

# Input 0 of layer lstm_5 is incompatible with the layer: expected ndim=3, found ndim=4. Full shape received: (None, 16, 32, 64)
# model.add(Bidirectional(LSTM(128)))
# model.add(Bidirectional(LSTM(64, input_shape=input_shape[0:-1])))
# model.add((LSTM(64, input_shape=input_shape[0:-1])))
# model.add(Dropout(0.2))

# model.add(Bidirectional(LSTM(128, input_shape=input_shape[0:-1])))
# model.add(Dropout(0.2))

# model.add(Attention())
# model.add(Dropout(0.2))

model.add(Dense(64, activation="tanh"))
model.add(Dropout(0.2))

model.add(Softmax())
model.add(Dropout(0.2))

# model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('elu'))
# model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4)))
# model.add(Dropout(0.25))

# model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('elu'))
# model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4)))
# model.add(Dropout(0.25))

# %%
model.add(Flatten())
# # FC
model.add(Dense(units=num_classes, activation='softmax'))

# Model compilation
opt = optimizers.Adam(lr=0.001, beta_1=0.9,  beta_2=0.999, amsgrad=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "Audio_CNN_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 259, 256)     6656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 259, 256)     1024
# _________________________________________________________________
# activation (Activation)      (None, 128, 259, 256)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 259, 256)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 129, 256)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 129, 256)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 129, 64)       409664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# dense (Dense)                (None, 16, 32, 64)        4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# softmax (Softmax)            (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 229383
# =================================================================
# Total params: 651,143
# Trainable params: 650,503
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ## Temp location for saving results
# # What was done:
# model = Sequential(name='Audio_CNN_2D')
#
# ### LFLB1
# model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', data_format='channels_last',input_shape=input_shape))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))
#
# model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.2))
#
# model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))
#
# model.add(MaxPooling2D(pool_size=(2,2), strides=(4,4)))
# model.add(Dropout(0.2))
#
# model.add(Dense(64, activation="tanh"))
# model.add(Dropout(0.2))
#
# model.add(Softmax())
# model.add(Dropout(0.2))
#
# model.add(Flatten())
# ### FC
# model.add(Dense(units=num_classes, activation='softmax'))
#
# ### Model compilation
# opt = optimizers.Adam(lr=0.001, beta_1=0.9,  beta_2=0.999, amsgrad=False)
# model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
#
# # Model summary:
# Model: "Audio_CNN_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 259, 256)     6656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 259, 256)     1024
# _________________________________________________________________
# activation (Activation)      (None, 128, 259, 256)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 259, 256)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 129, 256)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 129, 256)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 129, 64)       409664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# dense (Dense)                (None, 16, 32, 64)        4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# softmax (Softmax)            (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                393228
# =================================================================
# Total params: 814,988
# Trainable params: 814,348
# Non-trainable params: 640
# _________________________________________________________________
#
# # Accuracy:
# 50% accuracy

# %%
#Train Config

batch_size = 16
num_epochs = 100

# Model Training
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)
# Please change the model name accordingly.
mcp_save = ModelCheckpoint(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.h5', save_best_only=True, monitor='val_categorical_accuracy', mode='max')
cnnhistory=model.fit(x_traincnn, y_train, batch_size=batch_size, epochs=num_epochs,validation_data=(x_testcnn, y_test), callbacks=[mcp_save, lr_reduce])
# Out:
# Epoch 1/100
# 38/38 [==============================] - 6s 149ms/step - loss: 1.8793 - categorical_accuracy: 0.2470 - val_loss: 3.1681 - val_categorical_accuracy: 0.2000
# Epoch 2/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.6917 - categorical_accuracy: 0.3596 - val_loss: 2.3363 - val_categorical_accuracy: 0.2333
# Epoch 3/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.7088 - categorical_accuracy: 0.3182 - val_loss: 1.8353 - val_categorical_accuracy: 0.2833
# Epoch 4/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.6776 - categorical_accuracy: 0.3146 - val_loss: 1.8845 - val_categorical_accuracy: 0.2667
# Epoch 5/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.5769 - categorical_accuracy: 0.3824 - val_loss: 1.9096 - val_categorical_accuracy: 0.3167
# Epoch 6/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.5140 - categorical_accuracy: 0.3894 - val_loss: 1.7937 - val_categorical_accuracy: 0.3833
# Epoch 7/100
# 38/38 [==============================] - 5s 144ms/step - loss: 1.4385 - categorical_accuracy: 0.4479 - val_loss: 2.8078 - val_categorical_accuracy: 0.2000
# Epoch 8/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.4623 - categorical_accuracy: 0.4324 - val_loss: 2.8389 - val_categorical_accuracy: 0.2000
# Epoch 9/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.3448 - categorical_accuracy: 0.4897 - val_loss: 2.9962 - val_categorical_accuracy: 0.2000
# Epoch 10/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.2661 - categorical_accuracy: 0.5077 - val_loss: 2.7481 - val_categorical_accuracy: 0.2000
# Epoch 11/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.2105 - categorical_accuracy: 0.5580 - val_loss: 2.6168 - val_categorical_accuracy: 0.2000
# Epoch 12/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.2204 - categorical_accuracy: 0.5391 - val_loss: 1.6879 - val_categorical_accuracy: 0.3333
# Epoch 13/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.1380 - categorical_accuracy: 0.6287 - val_loss: 2.3555 - val_categorical_accuracy: 0.2333
# Epoch 14/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.1709 - categorical_accuracy: 0.5706 - val_loss: 2.0317 - val_categorical_accuracy: 0.4000
# Epoch 15/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.0821 - categorical_accuracy: 0.6097 - val_loss: 3.6452 - val_categorical_accuracy: 0.2000
# Epoch 16/100
# 38/38 [==============================] - 5s 143ms/step - loss: 1.0115 - categorical_accuracy: 0.6534 - val_loss: 3.3268 - val_categorical_accuracy: 0.1667
# Epoch 17/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.9958 - categorical_accuracy: 0.6696 - val_loss: 1.8514 - val_categorical_accuracy: 0.4167
# Epoch 18/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.9702 - categorical_accuracy: 0.6585 - val_loss: 2.2085 - val_categorical_accuracy: 0.3000
# Epoch 19/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.9636 - categorical_accuracy: 0.6873 - val_loss: 2.5097 - val_categorical_accuracy: 0.2500
# Epoch 20/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.9698 - categorical_accuracy: 0.7032 - val_loss: 2.1633 - val_categorical_accuracy: 0.2833
# Epoch 21/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.9164 - categorical_accuracy: 0.7176 - val_loss: 1.3156 - val_categorical_accuracy: 0.5167
# Epoch 22/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.9227 - categorical_accuracy: 0.6848 - val_loss: 1.4921 - val_categorical_accuracy: 0.4167
# Epoch 23/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.8390 - categorical_accuracy: 0.7172 - val_loss: 2.3166 - val_categorical_accuracy: 0.2167
# Epoch 24/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.8756 - categorical_accuracy: 0.7317 - val_loss: 1.3401 - val_categorical_accuracy: 0.5333
# Epoch 25/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.7686 - categorical_accuracy: 0.7727 - val_loss: 1.2375 - val_categorical_accuracy: 0.5000
# Epoch 26/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.7206 - categorical_accuracy: 0.8169 - val_loss: 1.4970 - val_categorical_accuracy: 0.4333
# Epoch 27/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.7120 - categorical_accuracy: 0.8118 - val_loss: 1.1165 - val_categorical_accuracy: 0.6333
# Epoch 28/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.7227 - categorical_accuracy: 0.7830 - val_loss: 2.7345 - val_categorical_accuracy: 0.2500
# Epoch 29/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6914 - categorical_accuracy: 0.7905 - val_loss: 3.1145 - val_categorical_accuracy: 0.2500
# Epoch 30/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6659 - categorical_accuracy: 0.8375 - val_loss: 1.4091 - val_categorical_accuracy: 0.4667
# Epoch 31/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6601 - categorical_accuracy: 0.8281 - val_loss: 1.2455 - val_categorical_accuracy: 0.5167
# Epoch 32/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6531 - categorical_accuracy: 0.8306 - val_loss: 1.1792 - val_categorical_accuracy: 0.5833
# Epoch 33/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6121 - categorical_accuracy: 0.8255 - val_loss: 1.8483 - val_categorical_accuracy: 0.4167
# Epoch 34/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6251 - categorical_accuracy: 0.8212 - val_loss: 1.2537 - val_categorical_accuracy: 0.4833
# Epoch 35/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6102 - categorical_accuracy: 0.8454 - val_loss: 1.5783 - val_categorical_accuracy: 0.4667
# Epoch 36/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5486 - categorical_accuracy: 0.8671 - val_loss: 1.9064 - val_categorical_accuracy: 0.3667
# Epoch 37/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5480 - categorical_accuracy: 0.8679 - val_loss: 1.3229 - val_categorical_accuracy: 0.5167
# Epoch 38/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5142 - categorical_accuracy: 0.8992 - val_loss: 1.3182 - val_categorical_accuracy: 0.4500
# Epoch 39/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5269 - categorical_accuracy: 0.8716 - val_loss: 1.5777 - val_categorical_accuracy: 0.3667
# Epoch 40/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5338 - categorical_accuracy: 0.8724 - val_loss: 1.3262 - val_categorical_accuracy: 0.5333
# Epoch 41/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5290 - categorical_accuracy: 0.8483 - val_loss: 1.1332 - val_categorical_accuracy: 0.6167
# Epoch 42/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4680 - categorical_accuracy: 0.8997 - val_loss: 1.2190 - val_categorical_accuracy: 0.5333
# Epoch 43/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4477 - categorical_accuracy: 0.9153 - val_loss: 1.4681 - val_categorical_accuracy: 0.4167
# Epoch 44/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4575 - categorical_accuracy: 0.9022 - val_loss: 1.1573 - val_categorical_accuracy: 0.5333
# Epoch 45/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.4233 - categorical_accuracy: 0.9109 - val_loss: 1.2096 - val_categorical_accuracy: 0.5167
# Epoch 46/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3838 - categorical_accuracy: 0.9267 - val_loss: 1.9371 - val_categorical_accuracy: 0.2833
# Epoch 47/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4154 - categorical_accuracy: 0.9051 - val_loss: 1.2211 - val_categorical_accuracy: 0.5500
# Epoch 48/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4060 - categorical_accuracy: 0.8956 - val_loss: 1.2295 - val_categorical_accuracy: 0.4667
# Epoch 49/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3804 - categorical_accuracy: 0.9487 - val_loss: 1.0249 - val_categorical_accuracy: 0.6667
# Epoch 50/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3471 - categorical_accuracy: 0.9567 - val_loss: 1.1289 - val_categorical_accuracy: 0.6000
# Epoch 51/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.3756 - categorical_accuracy: 0.9242 - val_loss: 1.2749 - val_categorical_accuracy: 0.4500
# Epoch 52/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3315 - categorical_accuracy: 0.9550 - val_loss: 1.2647 - val_categorical_accuracy: 0.5167
# Epoch 53/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.3507 - categorical_accuracy: 0.9249 - val_loss: 1.1141 - val_categorical_accuracy: 0.6000
# Epoch 54/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3244 - categorical_accuracy: 0.9626 - val_loss: 1.1793 - val_categorical_accuracy: 0.5167
# Epoch 55/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3275 - categorical_accuracy: 0.9707 - val_loss: 1.1498 - val_categorical_accuracy: 0.6167
# Epoch 56/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3144 - categorical_accuracy: 0.9464 - val_loss: 1.4673 - val_categorical_accuracy: 0.4500
# Epoch 57/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.3161 - categorical_accuracy: 0.9588 - val_loss: 1.0503 - val_categorical_accuracy: 0.6500
# Epoch 58/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2711 - categorical_accuracy: 0.9797 - val_loss: 1.4112 - val_categorical_accuracy: 0.4500
# Epoch 59/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3065 - categorical_accuracy: 0.9508 - val_loss: 1.0718 - val_categorical_accuracy: 0.5667
# Epoch 60/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2855 - categorical_accuracy: 0.9677 - val_loss: 1.1256 - val_categorical_accuracy: 0.6667
# Epoch 61/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2871 - categorical_accuracy: 0.9638 - val_loss: 1.0893 - val_categorical_accuracy: 0.5667
# Epoch 62/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2786 - categorical_accuracy: 0.9851 - val_loss: 1.1362 - val_categorical_accuracy: 0.5833
# Epoch 63/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2739 - categorical_accuracy: 0.9680 - val_loss: 1.4973 - val_categorical_accuracy: 0.3833
# Epoch 64/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2477 - categorical_accuracy: 0.9631 - val_loss: 1.3490 - val_categorical_accuracy: 0.5000
# Epoch 65/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2744 - categorical_accuracy: 0.9549 - val_loss: 1.0683 - val_categorical_accuracy: 0.5833
# Epoch 66/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2320 - categorical_accuracy: 0.9838 - val_loss: 1.1758 - val_categorical_accuracy: 0.5500
# Epoch 67/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.2299 - categorical_accuracy: 0.9879 - val_loss: 1.0583 - val_categorical_accuracy: 0.5000
# Epoch 68/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2517 - categorical_accuracy: 0.9692 - val_loss: 1.1653 - val_categorical_accuracy: 0.6167
# Epoch 69/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2102 - categorical_accuracy: 0.9891 - val_loss: 1.0744 - val_categorical_accuracy: 0.5667
# Epoch 70/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.2152 - categorical_accuracy: 0.9902 - val_loss: 1.0569 - val_categorical_accuracy: 0.6167
# Epoch 71/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.2070 - categorical_accuracy: 0.9869 - val_loss: 1.5395 - val_categorical_accuracy: 0.4500
# Epoch 72/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1815 - categorical_accuracy: 0.9881 - val_loss: 1.1470 - val_categorical_accuracy: 0.6000
# Epoch 73/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2275 - categorical_accuracy: 0.9812 - val_loss: 1.2833 - val_categorical_accuracy: 0.5000
# Epoch 74/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.2045 - categorical_accuracy: 0.9690 - val_loss: 1.0625 - val_categorical_accuracy: 0.5667
# Epoch 75/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1870 - categorical_accuracy: 0.9873 - val_loss: 1.1299 - val_categorical_accuracy: 0.5500
# Epoch 76/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1876 - categorical_accuracy: 0.9841 - val_loss: 1.3499 - val_categorical_accuracy: 0.5000
# Epoch 77/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1820 - categorical_accuracy: 0.9845 - val_loss: 1.2274 - val_categorical_accuracy: 0.5000
# Epoch 78/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1742 - categorical_accuracy: 0.9960 - val_loss: 1.5651 - val_categorical_accuracy: 0.4667
# Epoch 79/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1782 - categorical_accuracy: 0.9921 - val_loss: 1.2583 - val_categorical_accuracy: 0.5333
# Epoch 80/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1780 - categorical_accuracy: 0.9873 - val_loss: 1.2012 - val_categorical_accuracy: 0.5833
# Epoch 81/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.1794 - categorical_accuracy: 0.9907 - val_loss: 1.1717 - val_categorical_accuracy: 0.5167
# Epoch 82/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1604 - categorical_accuracy: 0.9927 - val_loss: 1.1482 - val_categorical_accuracy: 0.5000
# Epoch 83/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1719 - categorical_accuracy: 0.9959 - val_loss: 1.2272 - val_categorical_accuracy: 0.5333
# Epoch 84/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1568 - categorical_accuracy: 0.9926 - val_loss: 1.3897 - val_categorical_accuracy: 0.4500
# Epoch 85/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1616 - categorical_accuracy: 0.9904 - val_loss: 1.2772 - val_categorical_accuracy: 0.5167
# Epoch 86/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1626 - categorical_accuracy: 0.9909 - val_loss: 1.2333 - val_categorical_accuracy: 0.5167
# Epoch 87/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1800 - categorical_accuracy: 0.9875 - val_loss: 1.1668 - val_categorical_accuracy: 0.5167
# Epoch 88/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1649 - categorical_accuracy: 0.9959 - val_loss: 1.1792 - val_categorical_accuracy: 0.5000
# Epoch 89/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1600 - categorical_accuracy: 0.9917 - val_loss: 1.5134 - val_categorical_accuracy: 0.5000
# Epoch 90/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1420 - categorical_accuracy: 0.9946 - val_loss: 1.1507 - val_categorical_accuracy: 0.5500
# Epoch 91/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1439 - categorical_accuracy: 0.9917 - val_loss: 1.0298 - val_categorical_accuracy: 0.5333
# Epoch 92/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1425 - categorical_accuracy: 1.0000 - val_loss: 1.1951 - val_categorical_accuracy: 0.5500
# Epoch 93/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1271 - categorical_accuracy: 1.0000 - val_loss: 1.1731 - val_categorical_accuracy: 0.5500
# Epoch 94/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1259 - categorical_accuracy: 0.9985 - val_loss: 1.1746 - val_categorical_accuracy: 0.5833
# Epoch 95/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1353 - categorical_accuracy: 0.9899 - val_loss: 1.3049 - val_categorical_accuracy: 0.4667
# Epoch 96/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1213 - categorical_accuracy: 0.9967 - val_loss: 1.2422 - val_categorical_accuracy: 0.4833
# Epoch 97/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1217 - categorical_accuracy: 0.9963 - val_loss: 1.3156 - val_categorical_accuracy: 0.5167
# Epoch 98/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1089 - categorical_accuracy: 1.0000 - val_loss: 1.1572 - val_categorical_accuracy: 0.4833
# Epoch 99/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.1243 - categorical_accuracy: 0.9983 - val_loss: 1.6263 - val_categorical_accuracy: 0.4500
# Epoch 100/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1099 - categorical_accuracy: 0.9915 - val_loss: 1.3561 - val_categorical_accuracy: 0.5167

# %%
max(cnnhistory.history['val_categorical_accuracy'])
# Out:
# 0.6666666865348816

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['categorical_accuracy'])
plt.plot(cnnhistory.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Saving the model.json

import json
model_json = model.to_json()
with open(drive_prefix + "SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.json", "w") as json_file:
    json_file.write(model_json)

# %%
# loading json and creating model
from keras.models import model_from_json
json_file = open(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
from keras.models import load_model

# Returns a compiled model identical to the previous one
loaded_model.load_weights(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.h5')

# %%
#new_model = load_model('/content/gdrive/MyDrive/BME 3A/SYDE 522/Audio_2DCNN_4L.h5')

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
score = loaded_model.evaluate(x_testcnn, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# prints out most accurate epoch
# Out:
# accuracy: 66.67%

# %%
x_test_data = audios[(dataset_db['split'] == 'Test')]
y_test_data = dataset_db.emotion_lb[(dataset_db['split'] == 'Test')]

print(x_test_data.shape,y_test_data.shape)
# Out:
# (60, 128, 259, 1) (60,)

# %%
preds = loaded_model.predict(x_test_data,batch_size=16,verbose=1)
preds1=preds.argmax(axis=1)
abc = preds1.astype(int).flatten()
predictions = (lb.inverse_transform((abc)))
# Out:
# 4/4 [==============================] - 0s 32ms/step

# %%
preddf = pd.DataFrame({'predictedvalues': predictions})
preddf[:10]
# Out:
#   predictedvalues
# 0      female_sad
# 1      female_sad
# 2      female_sad
# 3      female_sad
# 4  female_neutral
# 5  female_neutral
# 6  female_neutral
# 7  female_neutral
# 8  female_disgust
# 9  female_neutral

# %%
actualdf = pd.DataFrame({'actualvalues': y_test_data})
actualdf[:10]
actualdf.index = range(len(actualdf.index))

# %%
finaldf = pd.concat([actualdf,preddf],axis=1)
finaldf.head()
# Out:
#      actualvalues predictedvalues
# 0  female_neutral      female_sad
# 1  female_neutral      female_sad
# 2  female_neutral      female_sad
# 3  female_neutral      female_sad
# 4  female_neutral  female_neutral

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (9,6), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import accuracy_score
y_true = finaldf.actualvalues
y_pred = finaldf.predictedvalues
accuracy_score(y_true, y_pred)*100
# Out:
# 55.00000000000001

# %%
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro') *100
# Out:
# 53.01226551226551

# %%
from sklearn.metrics import confusion_matrix
c = confusion_matrix(y_true, y_pred)
c
# Out:
# array([[5, 1, 0, 2, 0, 0, 0],
#        [0, 8, 0, 0, 0, 0, 0],
#        [1, 0, 4, 1, 0, 2, 0],
#        [1, 1, 1, 1, 1, 2, 1],
#        [0, 1, 0, 0, 7, 4, 0],
#        [0, 3, 1, 0, 2, 2, 0],
#        [1, 0, 1, 0, 0, 0, 6]])

# %%
class_names=sorted(set(finaldf.actualvalues))
print_confusion_matrix(c, class_names)
