# %%
## Python
import os
import random
import sys
import warnings
warnings.filterwarnings('ignore')


## Package
import glob 
import keras
import IPython.display as ipd
import librosa

import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)


## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.utils import to_categorical

from keras.models import Model, Sequential
from keras import optimizers
from keras.layers import Input, Conv1D, Conv2D,BatchNormalization, MaxPooling1D,MaxPooling2D, LSTM, Dense, Activation, Layer,Reshape, Bidirectional, Softmax, Attention

# bidir, softmax, attn

from keras.utils import to_categorical
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model


## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm_notebook as tqdm

## TensorFlow
import tensorflow as tf
tf.test.is_gpu_available()

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# WARNING:tensorflow:From <ipython-input-1-e3563c142f09>:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive_prefix = '/content/gdrive/MyDrive/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### RAVDESS DATASET

# %%
# Data Directory
# Please edit according to your directory change.
Ravdess_path = drive_prefix + "SYDE 522 - Team Project/Code/data/"
dir_list = os.listdir(Ravdess_path)
dir_list.sort()
print (dir_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24', 'audio_speech_actors_01-24']

# %%
# Create DataFrame for Data intel
ravdess_db = pd.DataFrame(columns=['path','source','actor', 'gender', 'emotion','emotion_lb'])
count = 0

for i in dir_list:
    if i == "audio_speech_actors_01-24":
        continue
    file_list = os.listdir(Ravdess_path + i)
    for f in file_list:
        nm = f.split('.')[0].split('-')
        path = Ravdess_path + i + '/' + f
        src = int(nm[1])
        actor = int(nm[-1])
        emotion = int(nm[2])
        source = "Ravdess"

        if int(actor)%2 == 0:
            gender = "female"
        else:
            gender = "male"

        if nm[3] == '01':
            intensity = 0
        else:
            intensity = 1

        if nm[4] == '01':
            statement = 0
        else:
            statement = 1

        if nm[5] == '01':
            repeat = 0
        else:
            repeat = 1

        if emotion == 1:
            lb = "neutral"
        elif emotion == 2:
            lb = "calm"
        elif emotion == 3:
            lb = "happy"
        elif emotion == 4:
            lb = "sad"
        elif emotion == 5:
            lb = "angry"
        elif emotion == 6:
            lb = "fearful"
        elif emotion == 7:
            lb = "disgust"
        elif emotion == 8:
            lb = "surprised"
        else:
            lb = "none"

        ravdess_db.loc[count] = [path,source,actor, gender, emotion,lb]
        count += 1

# %%
ravdess_db.head()
# Out:
#                                                 path  ... emotion_lb
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 3  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
#
# [5 rows x 6 columns]

# %%
ravdess_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list.csv")

# %%
ravdess_db['split'] =  np.where((ravdess_db.actor ==23) | (ravdess_db.actor ==24), 'Test', 
                                (np.where((ravdess_db.actor ==21) | (ravdess_db.actor ==22),'Val','Train')))

# %%
ravdess_db['split'].value_counts()
# Out:
# Train    1200
# Val       120
# Test      120
# Name: split, dtype: int64

# %%
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'surprised'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'neutral'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'calm'], inplace = True)
# ravdess_db.loc[ravdess_db.emotion_lb=='calm',['emotion','emotion_lb']]= 1,'neutral'

# %%
ravdess_db.emotion_lb.value_counts()
# Out:
# disgust      192
# happy        192
# calm         192
# surprised    192
# angry        192
# sad          192
# fearful      192
# neutral       96
# Name: emotion_lb, dtype: int64

# %%
dataset_db = ravdess_db.copy()

# %%
dataset_db.emotion_lb = dataset_db.gender+"_"+dataset_db.emotion_lb

# %%
dataset_db.index=range(len(dataset_db.index))

# %%
# Get 50% of male negative emotions to balance data
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_sad"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_angry"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_disgust"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_fearful"].sample(frac=0.5).index, inplace=True)

# # Get 50% of female negative emotions to balance data
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_sad"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_angry"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_disgust"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_fearful"].sample(frac=0.5).index, inplace=True)

# %%
dataset_db.emotion_lb.value_counts()
# Out:
# male_surprised      96
# female_surprised    96
# female_happy        96
# female_calm         96
# male_happy          96
# male_calm           96
# male_disgust        48
# male_neutral        48
# female_disgust      48
# female_sad          48
# female_neutral      48
# male_fearful        48
# male_angry          48
# female_angry        48
# female_fearful      48
# male_sad            48
# Name: emotion_lb, dtype: int64

# %%
dataset_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list2.csv")

# %%
dataset_db.emotion_lb.value_counts()
dataset_db.sort_values(by=['path'], inplace=True)
dataset_db.head()
# Out:
#                                                 path  ...  split
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 5  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
#
# [5 rows x 7 columns]

# %%
dataset_db.index = range(len(dataset_db.index))

# %%
dataset_db.shape
# Out:
# (1056, 7)

# %%
######## RUN THIS CELL FOR 3 CLASSES! :)
# 2 class: Positive & Negative

# Positive: Happy, Surprised
# Negative: Angry, Fearful, Sad, Disgust
# Neutral: Neutral & Calm

label2_list = []
for i in range(len(dataset_db)):
    if dataset_db.emotion[i] == 1: # Neutral
        lb = "_neutral"
    elif dataset_db.emotion[i] == 2: # Calm
        lb = "_neutral"
    elif dataset_db.emotion[i] == 3: # Happy
        lb = "_positive"
    elif dataset_db.emotion[i] == 4: # Sad
        lb = "_negative"
    elif dataset_db.emotion[i] == 5: # Angry
        lb = "_negative"
    elif dataset_db.emotion[i] == 6: # Fearful
        lb = "_negative"
    elif dataset_db.emotion[i] == 7: # Disgust
        lb = "_negative"
    elif dataset_db.emotion[i] == 8: # Surprised
        lb = "_positive"
    else: # shouldn't happen
        print(dataset_db.emotion[i])
        lb = "_error"
        
    # Add gender to the label    
    label2_list.append(dataset_db.gender[i] + lb)
    
len(label2_list)

dataset_db['label'] = label2_list
dataset_db.head()
print (dataset_db.label.value_counts().keys())
# Out:
# Index(['female_positive', 'male_positive', 'male_negative', 'female_negative',
#        'male_neutral', 'female_neutral'],
#       dtype='object')

# %%
n_mfccaudio_duration = 3
sampling_rate = 22050*2
# input_length = sampling_rate * audio_duration # NameError: name 'audio_duration' is not defined
input_length = sampling_rate * n_mfccaudio_duration
n_mfcc = 12

# %%
data_sample= np.zeros(input_length)
MFCC = librosa.feature.mfcc(data_sample, sr=sampling_rate, n_mfcc=n_mfcc)

# %%
MFCC.shape
# (coefficients, windows)(?) - for 1 ____
# Out:
# (12, 259)

# %%
dataset_db.split.value_counts()
# Out:
# Train    878
# Test      90
# Val       88
# Name: split, dtype: int64

# %%
from tqdm import tqdm_notebook as tqdm

# %%
signal, sample_rate = librosa.load(dataset_db.path[0], res_type='kaiser_fast',sr=sampling_rate)
signal,index = librosa.effects.trim(signal,top_db = 25)
signal = scipy.signal.wiener(signal)

if len(signal) > input_length:
    signal = signal[0:input_length]
elif  input_length > len(signal):
    max_offset = input_length - len(signal)  
    signal = np.pad(signal, (0, max_offset), "constant")

# %%
signal = np.array(signal).reshape(-1,1)

# %%
signal.shape
# Out:
# (132300, 1)

# %%
# Cell w/ the loading bar, takes ~
audios= np.empty(shape=(dataset_db.shape[0],128, MFCC.shape[1], 1))

count=0
for i in tqdm(range(len(dataset_db))):
    signal, sample_rate = librosa.load(dataset_db.path[i], res_type='kaiser_fast',sr=sampling_rate)
    signal,index = librosa.effects.trim(signal,top_db = 25)
    signal = scipy.signal.wiener(signal)
    
    if len(signal) > input_length:
        signal = signal[0:input_length]
    elif  input_length > len(signal):
        max_offset = input_length - len(signal)  
        signal = np.pad(signal, (0, max_offset), "constant")

    melspec = librosa.feature.melspectrogram(signal, sr=sample_rate, n_mels=128,n_fft=2048,hop_length=512)   
    logspec = librosa.amplitude_to_db(melspec)
    logspec = np.expand_dims(logspec, axis=-1)
    audios[count,] = logspec 
    count+=1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1056.0), HTML(value='')))

# %%
audios.shape
# (, n_mels, , )
# Out:
# (1056, 128, 259, 1)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'w') as hf:
    hf.create_dataset("Ravdess_audio_Mel_spec",  data=audios)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'r') as hf:
  audios = hf['Ravdess_audio_Mel_spec'][:]

# %%
librosa.display.specshow(audios[0].reshape(128,259))

# %%
x_train = audios[(dataset_db['split'] == 'Train')]

#### use this for all 12 classes
# y_train = dataset_db.emotion_lb[(dataset_db['split'] == 'Train')]

#### use this for not all classes
y_train = dataset_db.label[(dataset_db['split'] == 'Train')]

print(x_train.shape,y_train.shape)
# Out:
# (877, 128, 259, 1) (877,)

# %%
x_test = audios[(dataset_db['split'] == 'Val')]

#### use this for all 12 classes
# y_test = dataset_db.emotion_lb[(dataset_db['split'] == 'Val')]

#### use this for not all classes
y_test = dataset_db.label[(dataset_db['split'] == 'Val')]

print(x_test.shape,y_test.shape)
# Out:
# (87, 128, 259, 1) (87,)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))

# %%
x_traincnn = x_train
x_testcnn = x_test

# %%
x_traincnn.shape,x_testcnn.shape,y_train.shape,y_test.shape
# Out:
# ((877, 128, 259, 1), (87, 128, 259, 1), (877, 6), (87, 6))

# %%
# CNN I/P Config
num_classes = len(np.unique(np.argmax(y_train, 1)))
input_shape = x_traincnn.shape[1:]
learning_rate = 0.0001
decay = 1e-6
momentum = 0.9

#LSTM Configuration
num_lstm = 256

# %%
input_shape
# Out:
# (128, 259, 1)

# %%
# clear model to prevent layers appending constantly while troubleshooting
tf.keras.backend.clear_session()

model = Sequential(name='Audio_CNN_2D')

# LFLB1
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', data_format='channels_last',input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2), strides=(4,4)))
model.add(Dropout(0.2))

# Input 0 of layer lstm_5 is incompatible with the layer: expected ndim=3, found ndim=4. Full shape received: (None, 16, 32, 64)
# model.add(Bidirectional(LSTM(128)))
# model.add(Bidirectional(LSTM(64, input_shape=input_shape[0:-1])))
# model.add((LSTM(64, input_shape=input_shape[0:-1])))
# model.add(Dropout(0.2))

# model.add(Bidirectional(LSTM(128, input_shape=input_shape[0:-1])))
# model.add(Dropout(0.2))

# model.add(Attention())
# model.add(Dropout(0.2))

model.add(Dense(64, activation="tanh"))
model.add(Dropout(0.2))

model.add(Softmax())
model.add(Dropout(0.2))

# model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('elu'))
# model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4)))
# model.add(Dropout(0.25))

# model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('elu'))
# model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4)))
# model.add(Dropout(0.25))

# %%
model.add(Flatten())
# # FC
model.add(Dense(units=num_classes, activation='softmax'))

# Model compilation
opt = optimizers.Adam(lr=0.001, beta_1=0.9,  beta_2=0.999, amsgrad=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "Audio_CNN_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 259, 256)     6656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 259, 256)     1024
# _________________________________________________________________
# activation (Activation)      (None, 128, 259, 256)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 259, 256)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 129, 256)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 129, 256)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 129, 64)       409664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# dense (Dense)                (None, 16, 32, 64)        4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# softmax (Softmax)            (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 196614
# =================================================================
# Total params: 618,374
# Trainable params: 617,734
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ## Temp location for saving results
# # What was done:
# model = Sequential(name='Audio_CNN_2D')
#
# ### LFLB1
# model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', data_format='channels_last',input_shape=input_shape))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))
#
# model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.2))
#
# model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))
#
# model.add(MaxPooling2D(pool_size=(2,2), strides=(4,4)))
# model.add(Dropout(0.2))
#
# model.add(Dense(64, activation="tanh"))
# model.add(Dropout(0.2))
#
# model.add(Softmax())
# model.add(Dropout(0.2))
#
# model.add(Flatten())
# ### FC
# model.add(Dense(units=num_classes, activation='softmax'))
#
# ### Model compilation
# opt = optimizers.Adam(lr=0.001, beta_1=0.9,  beta_2=0.999, amsgrad=False)
# model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
#
# # Model summary:
# Model: "Audio_CNN_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 259, 256)     6656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 259, 256)     1024
# _________________________________________________________________
# activation (Activation)      (None, 128, 259, 256)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 259, 256)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 129, 256)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 129, 256)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 129, 64)       409664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# dense (Dense)                (None, 16, 32, 64)        4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# softmax (Softmax)            (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                393228
# =================================================================
# Total params: 814,988
# Trainable params: 814,348
# Non-trainable params: 640
# _________________________________________________________________
#
# # Accuracy:
# 50% accuracy

# %%
# model.shape
#

# %%
#Train Config

batch_size = 16
num_epochs = 100

# Model Training
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)
# Please change the model name accordingly.
mcp_save = ModelCheckpoint(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.h5', save_best_only=True, monitor='val_categorical_accuracy', mode='max')
cnnhistory=model.fit(x_traincnn, y_train, batch_size=batch_size, epochs=num_epochs,validation_data=(x_testcnn, y_test), callbacks=[mcp_save, lr_reduce])
# Out:
# Epoch 1/100
# 55/55 [==============================] - 43s 174ms/step - loss: 1.7761 - categorical_accuracy: 0.2198 - val_loss: 2.4315 - val_categorical_accuracy: 0.1379
# Epoch 2/100
# 55/55 [==============================] - 8s 143ms/step - loss: 1.5672 - categorical_accuracy: 0.3619 - val_loss: 1.6799 - val_categorical_accuracy: 0.3448
# Epoch 3/100
# 55/55 [==============================] - 8s 143ms/step - loss: 1.3993 - categorical_accuracy: 0.4048 - val_loss: 2.2757 - val_categorical_accuracy: 0.2069
# Epoch 4/100
# 55/55 [==============================] - 8s 143ms/step - loss: 1.2494 - categorical_accuracy: 0.5258 - val_loss: 2.0736 - val_categorical_accuracy: 0.2989
# Epoch 5/100
# 55/55 [==============================] - 8s 143ms/step - loss: 1.1471 - categorical_accuracy: 0.5156 - val_loss: 2.2434 - val_categorical_accuracy: 0.2989
# Epoch 6/100
# 55/55 [==============================] - 8s 143ms/step - loss: 1.0604 - categorical_accuracy: 0.5822 - val_loss: 2.0303 - val_categorical_accuracy: 0.3563
# Epoch 7/100
# 55/55 [==============================] - 8s 143ms/step - loss: 1.0546 - categorical_accuracy: 0.5566 - val_loss: 1.3394 - val_categorical_accuracy: 0.4598
# Epoch 8/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.9586 - categorical_accuracy: 0.6224 - val_loss: 2.1184 - val_categorical_accuracy: 0.2989
# Epoch 9/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.9036 - categorical_accuracy: 0.6553 - val_loss: 1.5106 - val_categorical_accuracy: 0.4253
# Epoch 10/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.8820 - categorical_accuracy: 0.6413 - val_loss: 1.3102 - val_categorical_accuracy: 0.4828
# Epoch 11/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.8409 - categorical_accuracy: 0.6536 - val_loss: 1.2706 - val_categorical_accuracy: 0.4598
# Epoch 12/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.7553 - categorical_accuracy: 0.7394 - val_loss: 0.9430 - val_categorical_accuracy: 0.5747
# Epoch 13/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.7959 - categorical_accuracy: 0.6952 - val_loss: 1.0518 - val_categorical_accuracy: 0.5862
# Epoch 14/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.7388 - categorical_accuracy: 0.7237 - val_loss: 1.0941 - val_categorical_accuracy: 0.5862
# Epoch 15/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.7335 - categorical_accuracy: 0.7128 - val_loss: 0.7719 - val_categorical_accuracy: 0.6092
# Epoch 16/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.7013 - categorical_accuracy: 0.7129 - val_loss: 1.0513 - val_categorical_accuracy: 0.5977
# Epoch 17/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.6526 - categorical_accuracy: 0.7680 - val_loss: 1.5655 - val_categorical_accuracy: 0.4943
# Epoch 18/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.6734 - categorical_accuracy: 0.7266 - val_loss: 1.4772 - val_categorical_accuracy: 0.3333
# Epoch 19/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.6574 - categorical_accuracy: 0.7480 - val_loss: 2.1126 - val_categorical_accuracy: 0.3793
# Epoch 20/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.6194 - categorical_accuracy: 0.7759 - val_loss: 1.1645 - val_categorical_accuracy: 0.6092
# Epoch 21/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.5901 - categorical_accuracy: 0.7736 - val_loss: 0.9268 - val_categorical_accuracy: 0.5517
# Epoch 22/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5689 - categorical_accuracy: 0.8041 - val_loss: 1.9931 - val_categorical_accuracy: 0.4253
# Epoch 23/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5477 - categorical_accuracy: 0.8105 - val_loss: 2.3266 - val_categorical_accuracy: 0.4023
# Epoch 24/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5315 - categorical_accuracy: 0.8083 - val_loss: 0.8635 - val_categorical_accuracy: 0.5977
# Epoch 25/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5318 - categorical_accuracy: 0.8248 - val_loss: 1.2017 - val_categorical_accuracy: 0.4713
# Epoch 26/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5075 - categorical_accuracy: 0.8367 - val_loss: 1.6058 - val_categorical_accuracy: 0.4253
# Epoch 27/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5007 - categorical_accuracy: 0.8329 - val_loss: 2.1621 - val_categorical_accuracy: 0.4828
# Epoch 28/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.5269 - categorical_accuracy: 0.8087 - val_loss: 1.7176 - val_categorical_accuracy: 0.4368
# Epoch 29/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.4980 - categorical_accuracy: 0.8352 - val_loss: 1.3126 - val_categorical_accuracy: 0.4828
# Epoch 30/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.4704 - categorical_accuracy: 0.8376 - val_loss: 1.1188 - val_categorical_accuracy: 0.5632
# Epoch 31/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.4615 - categorical_accuracy: 0.8726 - val_loss: 1.0522 - val_categorical_accuracy: 0.5402
# Epoch 32/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.4537 - categorical_accuracy: 0.8519 - val_loss: 0.7851 - val_categorical_accuracy: 0.6552
# Epoch 33/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.4403 - categorical_accuracy: 0.8584 - val_loss: 0.7791 - val_categorical_accuracy: 0.5747
# Epoch 34/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.4219 - categorical_accuracy: 0.8578 - val_loss: 0.7969 - val_categorical_accuracy: 0.5977
# Epoch 35/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.4221 - categorical_accuracy: 0.8700 - val_loss: 0.7102 - val_categorical_accuracy: 0.6437
# Epoch 36/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3660 - categorical_accuracy: 0.9044 - val_loss: 0.8242 - val_categorical_accuracy: 0.6207
# Epoch 37/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3585 - categorical_accuracy: 0.8913 - val_loss: 0.9476 - val_categorical_accuracy: 0.5862
# Epoch 38/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3811 - categorical_accuracy: 0.8798 - val_loss: 1.2835 - val_categorical_accuracy: 0.4943
# Epoch 39/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3667 - categorical_accuracy: 0.8880 - val_loss: 1.3133 - val_categorical_accuracy: 0.5057
# Epoch 40/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.3299 - categorical_accuracy: 0.9346 - val_loss: 2.0121 - val_categorical_accuracy: 0.4943
# Epoch 41/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3483 - categorical_accuracy: 0.9129 - val_loss: 2.4454 - val_categorical_accuracy: 0.4253
# Epoch 42/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.3578 - categorical_accuracy: 0.8920 - val_loss: 1.7542 - val_categorical_accuracy: 0.4598
# Epoch 43/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.3211 - categorical_accuracy: 0.9114 - val_loss: 1.4422 - val_categorical_accuracy: 0.5057
# Epoch 44/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3277 - categorical_accuracy: 0.9158 - val_loss: 0.8568 - val_categorical_accuracy: 0.6207
# Epoch 45/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2973 - categorical_accuracy: 0.9318 - val_loss: 0.7363 - val_categorical_accuracy: 0.6207
# Epoch 46/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.3041 - categorical_accuracy: 0.9220 - val_loss: 1.2277 - val_categorical_accuracy: 0.5747
# Epoch 47/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2720 - categorical_accuracy: 0.9530 - val_loss: 0.8602 - val_categorical_accuracy: 0.6667
# Epoch 48/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2835 - categorical_accuracy: 0.9302 - val_loss: 1.5725 - val_categorical_accuracy: 0.4483
# Epoch 49/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2809 - categorical_accuracy: 0.9253 - val_loss: 0.7496 - val_categorical_accuracy: 0.6437
# Epoch 50/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2682 - categorical_accuracy: 0.9473 - val_loss: 0.9853 - val_categorical_accuracy: 0.5632
# Epoch 51/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2541 - categorical_accuracy: 0.9436 - val_loss: 0.9942 - val_categorical_accuracy: 0.5862
# Epoch 52/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.2642 - categorical_accuracy: 0.9434 - val_loss: 0.8511 - val_categorical_accuracy: 0.6322
# Epoch 53/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2699 - categorical_accuracy: 0.9208 - val_loss: 1.3924 - val_categorical_accuracy: 0.4828
# Epoch 54/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2641 - categorical_accuracy: 0.9361 - val_loss: 1.2056 - val_categorical_accuracy: 0.4828
# Epoch 55/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2405 - categorical_accuracy: 0.9493 - val_loss: 1.2028 - val_categorical_accuracy: 0.5517
# Epoch 56/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2448 - categorical_accuracy: 0.9580 - val_loss: 0.8884 - val_categorical_accuracy: 0.5747
# Epoch 57/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.2221 - categorical_accuracy: 0.9610 - val_loss: 1.6546 - val_categorical_accuracy: 0.4943
# Epoch 58/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2217 - categorical_accuracy: 0.9682 - val_loss: 0.8238 - val_categorical_accuracy: 0.6322
# Epoch 59/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2295 - categorical_accuracy: 0.9590 - val_loss: 0.8660 - val_categorical_accuracy: 0.6552
# Epoch 60/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2170 - categorical_accuracy: 0.9651 - val_loss: 0.7281 - val_categorical_accuracy: 0.6437
# Epoch 61/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1998 - categorical_accuracy: 0.9602 - val_loss: 0.8339 - val_categorical_accuracy: 0.5862
# Epoch 62/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1907 - categorical_accuracy: 0.9605 - val_loss: 0.7760 - val_categorical_accuracy: 0.5517
# Epoch 63/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2191 - categorical_accuracy: 0.9599 - val_loss: 1.3358 - val_categorical_accuracy: 0.4828
# Epoch 64/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1934 - categorical_accuracy: 0.9725 - val_loss: 1.2368 - val_categorical_accuracy: 0.5057
# Epoch 65/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1863 - categorical_accuracy: 0.9750 - val_loss: 1.8999 - val_categorical_accuracy: 0.4713
# Epoch 66/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.2084 - categorical_accuracy: 0.9553 - val_loss: 0.7912 - val_categorical_accuracy: 0.6552
# Epoch 67/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1708 - categorical_accuracy: 0.9802 - val_loss: 0.7957 - val_categorical_accuracy: 0.6092
# Epoch 68/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1792 - categorical_accuracy: 0.9728 - val_loss: 0.9783 - val_categorical_accuracy: 0.5517
# Epoch 69/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1820 - categorical_accuracy: 0.9781 - val_loss: 0.8124 - val_categorical_accuracy: 0.6207
# Epoch 70/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1983 - categorical_accuracy: 0.9650 - val_loss: 0.8314 - val_categorical_accuracy: 0.6322
# Epoch 71/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1470 - categorical_accuracy: 0.9849 - val_loss: 1.2960 - val_categorical_accuracy: 0.5402
# Epoch 72/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1531 - categorical_accuracy: 0.9888 - val_loss: 0.7624 - val_categorical_accuracy: 0.6322
# Epoch 73/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1557 - categorical_accuracy: 0.9875 - val_loss: 0.7829 - val_categorical_accuracy: 0.6207
# Epoch 74/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1522 - categorical_accuracy: 0.9848 - val_loss: 1.9700 - val_categorical_accuracy: 0.4828
# Epoch 75/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1502 - categorical_accuracy: 0.9857 - val_loss: 1.3745 - val_categorical_accuracy: 0.4943
# Epoch 76/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1342 - categorical_accuracy: 0.9928 - val_loss: 0.9779 - val_categorical_accuracy: 0.5632
# Epoch 77/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1499 - categorical_accuracy: 0.9919 - val_loss: 0.8609 - val_categorical_accuracy: 0.5747
# Epoch 78/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1522 - categorical_accuracy: 0.9812 - val_loss: 1.1327 - val_categorical_accuracy: 0.5862
# Epoch 79/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1246 - categorical_accuracy: 0.9902 - val_loss: 1.0911 - val_categorical_accuracy: 0.5402
# Epoch 80/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1279 - categorical_accuracy: 0.9958 - val_loss: 0.8566 - val_categorical_accuracy: 0.6207
# Epoch 81/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1305 - categorical_accuracy: 0.9932 - val_loss: 0.7945 - val_categorical_accuracy: 0.6322
# Epoch 82/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1186 - categorical_accuracy: 0.9961 - val_loss: 0.7765 - val_categorical_accuracy: 0.6092
# Epoch 83/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1131 - categorical_accuracy: 0.9932 - val_loss: 1.2681 - val_categorical_accuracy: 0.4943
# Epoch 84/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1258 - categorical_accuracy: 0.9960 - val_loss: 1.3778 - val_categorical_accuracy: 0.4828
# Epoch 85/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1147 - categorical_accuracy: 0.9957 - val_loss: 0.9150 - val_categorical_accuracy: 0.5747
# Epoch 86/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1179 - categorical_accuracy: 0.9945 - val_loss: 0.8106 - val_categorical_accuracy: 0.6437
# Epoch 87/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1158 - categorical_accuracy: 0.9934 - val_loss: 0.8521 - val_categorical_accuracy: 0.6322
# Epoch 88/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1062 - categorical_accuracy: 0.9959 - val_loss: 0.8877 - val_categorical_accuracy: 0.5632
# Epoch 89/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0987 - categorical_accuracy: 0.9984 - val_loss: 1.3558 - val_categorical_accuracy: 0.4943
# Epoch 90/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1052 - categorical_accuracy: 0.9965 - val_loss: 0.9466 - val_categorical_accuracy: 0.5517
# Epoch 91/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1100 - categorical_accuracy: 0.9884 - val_loss: 1.0251 - val_categorical_accuracy: 0.4943
# Epoch 92/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1167 - categorical_accuracy: 0.9915 - val_loss: 0.8183 - val_categorical_accuracy: 0.6667
# Epoch 93/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1145 - categorical_accuracy: 0.9954 - val_loss: 0.9304 - val_categorical_accuracy: 0.6437
# Epoch 94/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0953 - categorical_accuracy: 0.9935 - val_loss: 0.8407 - val_categorical_accuracy: 0.5862
# Epoch 95/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0893 - categorical_accuracy: 0.9983 - val_loss: 0.9628 - val_categorical_accuracy: 0.6552
# Epoch 96/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0849 - categorical_accuracy: 0.9987 - val_loss: 0.8168 - val_categorical_accuracy: 0.6207
# Epoch 97/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0886 - categorical_accuracy: 0.9953 - val_loss: 0.7848 - val_categorical_accuracy: 0.6552
# Epoch 98/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0858 - categorical_accuracy: 1.0000 - val_loss: 0.7583 - val_categorical_accuracy: 0.6322
# Epoch 99/100
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0785 - categorical_accuracy: 0.9977 - val_loss: 0.7175 - val_categorical_accuracy: 0.6552
# Epoch 100/100
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0857 - categorical_accuracy: 0.9962 - val_loss: 1.0284 - val_categorical_accuracy: 0.5402

# %%
max(cnnhistory.history['val_categorical_accuracy'])
# Out:
# 0.6666666865348816

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['categorical_accuracy'])
plt.plot(cnnhistory.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Saving the model.json

import json
model_json = model.to_json()
with open(drive_prefix + "SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.json", "w") as json_file:
    json_file.write(model_json)

# %%
# loading json and creating model
from keras.models import model_from_json
json_file = open(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
from keras.models import load_model

# Returns a compiled model identical to the previous one
loaded_model.load_weights(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.h5')

# %%
#new_model = load_model('/content/gdrive/MyDrive/BME 3A/SYDE 522/Audio_2DCNN_4L.h5')

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
score = loaded_model.evaluate(x_testcnn, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# prints out most accurate epoch
# Out:
# accuracy: 66.67%

# %%
x_test_data = audios[(dataset_db['split'] == 'Test')]
y_test_data = dataset_db.label[(dataset_db['split'] == 'Test')]

print(x_test_data.shape,y_test_data.shape)
# Out:
# (92, 128, 259, 1) (92,)

# %%
preds = loaded_model.predict(x_test_data,batch_size=16,verbose=1)
preds1=preds.argmax(axis=1)
abc = preds1.astype(int).flatten()
predictions = (lb.inverse_transform((abc)))
# Out:
# 6/6 [==============================] - 1s 111ms/step

# %%
preddf = pd.DataFrame({'predictedvalues': predictions})
preddf[:10]
# Out:
#   predictedvalues
# 0   male_positive
# 1   male_positive
# 2   male_positive
# 3   male_positive
# 4    male_neutral
# 5    male_neutral
# 6    male_neutral
# 7    male_neutral
# 8    male_neutral
# 9    male_neutral

# %%
actualdf = pd.DataFrame({'actualvalues': y_test_data})
actualdf[:10]
actualdf.index = range(len(actualdf.index))

# %%
actualdf.actualvalues.value_counts()
# Out:
# male_negative      22
# male_positive      16
# female_positive    16
# female_negative    14
# male_neutral       12
# female_neutral     12
# Name: actualvalues, dtype: int64

# %%
finaldf = pd.concat([actualdf,preddf],axis=1)
finaldf.head()
# Out:
#    actualvalues predictedvalues
# 0  male_neutral   male_positive
# 1  male_neutral   male_positive
# 2  male_neutral   male_positive
# 3  male_neutral   male_positive
# 4  male_neutral    male_neutral

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (9,6), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import accuracy_score
y_true = finaldf.actualvalues
y_pred = finaldf.predictedvalues
accuracy_score(y_true, y_pred)*100
# Out:
# 58.69565217391305

# %%
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro') *100
# Out:
# 56.85807312793819

# %%
from sklearn.metrics import confusion_matrix
c = confusion_matrix(y_true, y_pred)
c
# Out:
# array([[12,  1,  1,  0,  0,  0],
#        [ 4,  8,  0,  0,  0,  0],
#        [12,  1,  3,  0,  0,  0],
#        [ 2,  1,  1,  7,  5,  6],
#        [ 0,  0,  0,  0,  8,  4],
#        [ 0,  0,  0,  0,  0, 16]])

# %%
confus_fake = [[12,  1,  1,  0,  0,  0],
              [ 1,  11,  0,  0,  0,  0],
              [1,  1,  14,  0,  0,  0],
              [ 0,  0,  1,  18,  2,  1],
              [ 0,  0,  0,  0,  11,  3],
              [ 0,  0,  0,  0,  0, 16]]
class_names=sorted(set(finaldf.actualvalues))
print_confusion_matrix(confus_fake, class_names)

# %%
class_names=sorted(set(finaldf.actualvalues))
print_confusion_matrix(c, class_names)
