# %%
## Python
import os
import random
import sys
import warnings
warnings.filterwarnings('ignore')


## Package
import glob 
import keras
import IPython.display as ipd
import librosa

import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)


## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.utils import to_categorical

from keras.models import Model, Sequential
from keras import optimizers
from keras.layers import Input, Conv1D, Conv2D,BatchNormalization, MaxPooling1D,MaxPooling2D, LSTM, Dense, Activation, Layer,Reshape, Bidirectional, Softmax, Attention

# bidir, softmax, attn

from keras.utils import to_categorical
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model


## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm_notebook as tqdm

## TensorFlow
import tensorflow as tf
tf.test.is_gpu_available()

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# WARNING:tensorflow:From <ipython-input-1-e3563c142f09>:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive_prefix = '/content/gdrive/MyDrive/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### RAVDESS DATASET

# %%
# Data Directory
# Please edit according to your directory change.
Ravdess_path = drive_prefix + "SYDE 522 - Team Project/Code/data/"
dir_list = os.listdir(Ravdess_path)
dir_list.sort()
print (dir_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24', 'audio_speech_actors_01-24']

# %%
# Create DataFrame for Data intel
ravdess_db = pd.DataFrame(columns=['path','source','actor', 'gender', 'emotion','emotion_lb'])
count = 0

for i in dir_list:
    if i == "audio_speech_actors_01-24":
        continue
    file_list = os.listdir(Ravdess_path + i)
    for f in file_list:
        nm = f.split('.')[0].split('-')
        path = Ravdess_path + i + '/' + f
        src = int(nm[1])
        actor = int(nm[-1])
        emotion = int(nm[2])
        source = "Ravdess"

        if int(actor)%2 == 0:
            gender = "female"
        else:
            gender = "male"

        if nm[3] == '01':
            intensity = 0
        else:
            intensity = 1

        if nm[4] == '01':
            statement = 0
        else:
            statement = 1

        if nm[5] == '01':
            repeat = 0
        else:
            repeat = 1

        if emotion == 1:
            lb = "neutral"
        elif emotion == 2:
            lb = "calm"
        elif emotion == 3:
            lb = "happy"
        elif emotion == 4:
            lb = "sad"
        elif emotion == 5:
            lb = "angry"
        elif emotion == 6:
            lb = "fearful"
        elif emotion == 7:
            lb = "disgust"
        elif emotion == 8:
            lb = "surprised"
        else:
            lb = "none"

        ravdess_db.loc[count] = [path,source,actor, gender, emotion,lb]
        count += 1

# %%
ravdess_db.head()
# Out:
#                                                 path  ... emotion_lb
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 3  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
#
# [5 rows x 6 columns]

# %%
ravdess_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list.csv")

# %%
ravdess_db['split'] =  np.where((ravdess_db.actor ==23) | (ravdess_db.actor ==24), 'Test', 
                                (np.where((ravdess_db.actor ==21) | (ravdess_db.actor ==22),'Val','Train')))

# %%
ravdess_db['split'].value_counts()
# Out:
# Train    1200
# Val       120
# Test      120
# Name: split, dtype: int64

# %%
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'surprised'], inplace = True)
ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'angry'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'neutral'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'calm'], inplace = True)
ravdess_db.loc[ravdess_db.emotion_lb=='calm',['emotion','emotion_lb']]= 1,'neutral'

# %%
ravdess_db.emotion_lb.value_counts()
# Out:
# neutral      288
# surprised    192
# sad          192
# fearful      192
# happy        192
# disgust      192
# Name: emotion_lb, dtype: int64

# %%
dataset_db = ravdess_db.copy()

# %%
dataset_db.emotion_lb = dataset_db.gender+"_"+dataset_db.emotion_lb

# %%
dataset_db.index=range(len(dataset_db.index))

# %%
# Get 50% of male negative emotions to balance data
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_sad"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_angry"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_disgust"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_fearful"].sample(frac=0.5).index, inplace=True)

# # Get 50% of female negative emotions to balance data
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_sad"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_angry"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_disgust"].sample(frac=0.5).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_fearful"].sample(frac=0.5).index, inplace=True)

# %%
dataset_db.emotion_lb.value_counts()
# Out:
# male_neutral        144
# female_neutral      144
# female_happy         96
# male_surprised       96
# male_happy           96
# female_surprised     96
# female_disgust       48
# male_sad             48
# male_disgust         48
# female_fearful       48
# female_sad           48
# male_fearful         48
# Name: emotion_lb, dtype: int64

# %%
dataset_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list2.csv")

# %%
dataset_db.emotion_lb.value_counts()
dataset_db.sort_values(by=['path'], inplace=True)
dataset_db.head()
# Out:
#                                                 path  ...  split
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 5  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
#
# [5 rows x 7 columns]

# %%
dataset_db.index = range(len(dataset_db.index))

# %%
dataset_db.shape
# Out:
# (960, 7)

# %%
######## RUN THIS CELL FOR 3 CLASSES! :)
# 2 class: Positive & Negative

# Positive: Happy, Surprised
# Negative: Angry, Fearful, Sad, Disgust
# Neutral: Neutral & Calm

label2_list = []
for i in range(len(dataset_db)):
    if dataset_db.emotion[i] == 1: # Neutral
        lb = "_neutral"
    elif dataset_db.emotion[i] == 2: # Calm
        lb = "_neutral"
    elif dataset_db.emotion[i] == 3: # Happy
        lb = "_positive"
    elif dataset_db.emotion[i] == 4: # Sad
        lb = "_negative"
    elif dataset_db.emotion[i] == 5: # Angry
        lb = "_negative"
    elif dataset_db.emotion[i] == 6: # Fearful
        lb = "_negative"
    elif dataset_db.emotion[i] == 7: # Disgust
        lb = "_negative"
    elif dataset_db.emotion[i] == 8: # Surprised
        lb = "_positive"
    else: # shouldn't happen
        print(dataset_db.emotion[i])
        lb = "_error"
        
    # Add gender to the label    
    label2_list.append(dataset_db.gender[i] + lb)
    
len(label2_list)

dataset_db['label'] = label2_list
dataset_db.head()
print (dataset_db.label.value_counts().keys())
# Out:
# Index(['male_positive', 'female_positive', 'male_neutral', 'female_negative',
#        'female_neutral', 'male_negative'],
#       dtype='object')

# %%
dataset_db.label.value_counts()
# Out:
# male_positive      192
# female_positive    192
# male_neutral       144
# female_negative    144
# female_neutral     144
# male_negative      144
# Name: label, dtype: int64

# %%
n_mfccaudio_duration = 3
sampling_rate = 22050*2
# input_length = sampling_rate * audio_duration # NameError: name 'audio_duration' is not defined
input_length = sampling_rate * n_mfccaudio_duration
n_mfcc = 12

# %%
data_sample= np.zeros(input_length)
MFCC = librosa.feature.mfcc(data_sample, sr=sampling_rate, n_mfcc=n_mfcc)

# %%
MFCC.shape
# (coefficients, windows)(?) - for 1 ____
# Out:
# (12, 259)

# %%
dataset_db.split.value_counts()
# Out:
# Train    805
# Val       81
# Test      74
# Name: split, dtype: int64

# %%
from tqdm import tqdm_notebook as tqdm

# %%
signal, sample_rate = librosa.load(dataset_db.path[0], res_type='kaiser_fast',sr=sampling_rate)
signal,index = librosa.effects.trim(signal,top_db = 25)
signal = scipy.signal.wiener(signal)

if len(signal) > input_length:
    signal = signal[0:input_length]
elif  input_length > len(signal):
    max_offset = input_length - len(signal)  
    signal = np.pad(signal, (0, max_offset), "constant")

# %%
signal = np.array(signal).reshape(-1,1)

# %%
signal.shape
# Out:
# (132300, 1)

# %%
# Cell w/ the loading bar, takes ~
audios= np.empty(shape=(dataset_db.shape[0],128, MFCC.shape[1], 1))

count=0
for i in tqdm(range(len(dataset_db))):
    signal, sample_rate = librosa.load(dataset_db.path[i], res_type='kaiser_fast',sr=sampling_rate)
    signal,index = librosa.effects.trim(signal,top_db = 25)
    signal = scipy.signal.wiener(signal)
    
    if len(signal) > input_length:
        signal = signal[0:input_length]
    elif  input_length > len(signal):
        max_offset = input_length - len(signal)  
        signal = np.pad(signal, (0, max_offset), "constant")

    melspec = librosa.feature.melspectrogram(signal, sr=sample_rate, n_mels=128,n_fft=2048,hop_length=512)   
    logspec = librosa.amplitude_to_db(melspec)
    logspec = np.expand_dims(logspec, axis=-1)
    audios[count,] = logspec 
    count+=1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=960.0), HTML(value='')))

# %%
audios.shape
# Out:
# (960, 128, 259, 1)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'w') as hf:
    hf.create_dataset("Ravdess_audio_Mel_spec",  data=audios)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'r') as hf:
  audios = hf['Ravdess_audio_Mel_spec'][:]

# %%
librosa.display.specshow(audios[0].reshape(128,259))

# %%
x_train = audios[(dataset_db['split'] == 'Train')]

#### use this for all 12 classes
# y_train = dataset_db.emotion_lb[(dataset_db['split'] == 'Train')]

#### use this for not all classes
y_train = dataset_db.label[(dataset_db['split'] == 'Train')]

print(x_train.shape,y_train.shape)
# Out:
# (805, 128, 259, 1) (805,)

# %%
x_test = audios[(dataset_db['split'] == 'Val')]

#### use this for all 12 classes
# y_test = dataset_db.emotion_lb[(dataset_db['split'] == 'Val')]

#### use this for not all classes
y_test = dataset_db.label[(dataset_db['split'] == 'Val')]

print(x_test.shape,y_test.shape)
# Out:
# (81, 128, 259, 1) (81,)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))

# %%
x_traincnn = x_train
x_testcnn = x_test

# %%
x_traincnn.shape,x_testcnn.shape,y_train.shape,y_test.shape
# Out:
# ((805, 128, 259, 1), (81, 128, 259, 1), (805, 6), (81, 6))

# %%
# CNN I/P Config
num_classes = len(np.unique(np.argmax(y_train, 1)))
input_shape = x_traincnn.shape[1:]
learning_rate = 0.0001
decay = 1e-6
momentum = 0.9

# %%
input_shape
# Out:
# (128, 259, 1)

# %%
# clear model to prevent layers appending constantly while troubleshooting
tf.keras.backend.clear_session()

model = Sequential(name='Audio_CNN_2D')

# LFLB1
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', data_format='channels_last',input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))

# model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2), strides=(4,4)))
model.add(Dropout(0.2))

model.add(Dense(64, activation="tanh"))
model.add(Dropout(0.2))

model.add(Softmax())
model.add(Dropout(0.2))

# %%
model.add(Flatten())
# # FC
model.add(Dense(units=num_classes, activation='softmax'))

# Model compilation
opt = optimizers.Adam(lr=0.001, beta_1=0.9,  beta_2=0.999, amsgrad=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "Audio_CNN_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 259, 256)     6656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 259, 256)     1024
# _________________________________________________________________
# activation (Activation)      (None, 128, 259, 256)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 259, 256)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 129, 256)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 129, 256)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 129, 64)       409664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# dense (Dense)                (None, 16, 32, 64)        4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# softmax (Softmax)            (None, 16, 32, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 196614
# =================================================================
# Total params: 618,374
# Trainable params: 617,734
# Non-trainable params: 640
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file= drive_prefix + 'SYDE 522 - Team Project/Code/model/model_plot_CNN_6_Classes.png', show_shapes=True, show_layer_names=True)

# %%
#Train Config

batch_size = 16
num_epochs = 100
# num_epochs = 75
# num_epochs = 130

# Model Training
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)
# Please change the model name accordingly.
mcp_save = ModelCheckpoint(drive_prefix + 'SYDE 522 - Team Project/Code/model/CNN-6-Classes.h5', save_best_only=True, monitor='val_categorical_accuracy', mode='max')
cnnhistory=model.fit(x_traincnn, y_train, batch_size=batch_size, epochs=num_epochs,validation_data=(x_testcnn, y_test), callbacks=[mcp_save, lr_reduce])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 13s 163ms/step - loss: 1.7314 - categorical_accuracy: 0.2314 - val_loss: 2.2613 - val_categorical_accuracy: 0.1481
# Epoch 2/100
# 51/51 [==============================] - 7s 141ms/step - loss: 1.5426 - categorical_accuracy: 0.3828 - val_loss: 1.7811 - val_categorical_accuracy: 0.3580
# Epoch 3/100
# 51/51 [==============================] - 7s 142ms/step - loss: 1.3891 - categorical_accuracy: 0.4578 - val_loss: 2.3375 - val_categorical_accuracy: 0.1975
# Epoch 4/100
# 51/51 [==============================] - 7s 141ms/step - loss: 1.2043 - categorical_accuracy: 0.5159 - val_loss: 1.9674 - val_categorical_accuracy: 0.1728
# Epoch 5/100
# 51/51 [==============================] - 7s 141ms/step - loss: 1.1409 - categorical_accuracy: 0.5557 - val_loss: 2.1115 - val_categorical_accuracy: 0.3827
# Epoch 6/100
# 51/51 [==============================] - 7s 142ms/step - loss: 1.0908 - categorical_accuracy: 0.5562 - val_loss: 2.2925 - val_categorical_accuracy: 0.3827
# Epoch 7/100
# 51/51 [==============================] - 7s 142ms/step - loss: 1.0016 - categorical_accuracy: 0.6237 - val_loss: 1.8170 - val_categorical_accuracy: 0.6049
# Epoch 8/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.9691 - categorical_accuracy: 0.6171 - val_loss: 1.2624 - val_categorical_accuracy: 0.4568
# Epoch 9/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.8687 - categorical_accuracy: 0.6887 - val_loss: 1.3910 - val_categorical_accuracy: 0.5185
# Epoch 10/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.9387 - categorical_accuracy: 0.5970 - val_loss: 2.1562 - val_categorical_accuracy: 0.4568
# Epoch 11/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.8178 - categorical_accuracy: 0.6787 - val_loss: 0.9489 - val_categorical_accuracy: 0.5802
# Epoch 12/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.7953 - categorical_accuracy: 0.7172 - val_loss: 1.7114 - val_categorical_accuracy: 0.5679
# Epoch 13/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.7530 - categorical_accuracy: 0.7280 - val_loss: 0.8343 - val_categorical_accuracy: 0.5926
# Epoch 14/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.7633 - categorical_accuracy: 0.7023 - val_loss: 0.9374 - val_categorical_accuracy: 0.5926
# Epoch 15/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.6968 - categorical_accuracy: 0.7252 - val_loss: 0.8781 - val_categorical_accuracy: 0.6543
# Epoch 16/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.6786 - categorical_accuracy: 0.7615 - val_loss: 1.1931 - val_categorical_accuracy: 0.4691
# Epoch 17/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.7198 - categorical_accuracy: 0.7357 - val_loss: 1.0681 - val_categorical_accuracy: 0.5556
# Epoch 18/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.6767 - categorical_accuracy: 0.7454 - val_loss: 1.2884 - val_categorical_accuracy: 0.6790
# Epoch 19/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.6086 - categorical_accuracy: 0.7946 - val_loss: 0.7823 - val_categorical_accuracy: 0.6296
# Epoch 20/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.6065 - categorical_accuracy: 0.7753 - val_loss: 1.0219 - val_categorical_accuracy: 0.6296
# Epoch 21/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.5900 - categorical_accuracy: 0.7748 - val_loss: 0.9807 - val_categorical_accuracy: 0.6173
# Epoch 22/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.5784 - categorical_accuracy: 0.7738 - val_loss: 1.1875 - val_categorical_accuracy: 0.5802
# Epoch 23/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.5550 - categorical_accuracy: 0.8188 - val_loss: 1.7234 - val_categorical_accuracy: 0.4938
# Epoch 24/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.5721 - categorical_accuracy: 0.7963 - val_loss: 0.9167 - val_categorical_accuracy: 0.6173
# Epoch 25/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.5263 - categorical_accuracy: 0.8165 - val_loss: 1.0094 - val_categorical_accuracy: 0.5926
# Epoch 26/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4770 - categorical_accuracy: 0.8609 - val_loss: 0.8555 - val_categorical_accuracy: 0.6049
# Epoch 27/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4675 - categorical_accuracy: 0.8512 - val_loss: 0.8412 - val_categorical_accuracy: 0.6173
# Epoch 28/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.4642 - categorical_accuracy: 0.8592 - val_loss: 0.8951 - val_categorical_accuracy: 0.6667
# Epoch 29/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.5039 - categorical_accuracy: 0.8348 - val_loss: 0.8462 - val_categorical_accuracy: 0.6420
# Epoch 30/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.4681 - categorical_accuracy: 0.8332 - val_loss: 0.7804 - val_categorical_accuracy: 0.6420
# Epoch 31/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4609 - categorical_accuracy: 0.8580 - val_loss: 1.0242 - val_categorical_accuracy: 0.6049
# Epoch 32/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4506 - categorical_accuracy: 0.8565 - val_loss: 0.8198 - val_categorical_accuracy: 0.6667
# Epoch 33/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4578 - categorical_accuracy: 0.8525 - val_loss: 1.0035 - val_categorical_accuracy: 0.5926
# Epoch 34/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4250 - categorical_accuracy: 0.8631 - val_loss: 0.8622 - val_categorical_accuracy: 0.6049
# Epoch 35/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.4254 - categorical_accuracy: 0.8688 - val_loss: 0.8658 - val_categorical_accuracy: 0.6173
# Epoch 36/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3948 - categorical_accuracy: 0.8862 - val_loss: 1.4249 - val_categorical_accuracy: 0.4938
# Epoch 37/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3622 - categorical_accuracy: 0.9100 - val_loss: 0.9283 - val_categorical_accuracy: 0.5926
# Epoch 38/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.3878 - categorical_accuracy: 0.8932 - val_loss: 0.8388 - val_categorical_accuracy: 0.6049
# Epoch 39/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3571 - categorical_accuracy: 0.9101 - val_loss: 0.8648 - val_categorical_accuracy: 0.6049
# Epoch 40/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3582 - categorical_accuracy: 0.9111 - val_loss: 0.8433 - val_categorical_accuracy: 0.6296
# Epoch 41/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.3384 - categorical_accuracy: 0.8986 - val_loss: 1.0719 - val_categorical_accuracy: 0.6049
# Epoch 42/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3382 - categorical_accuracy: 0.9095 - val_loss: 1.2316 - val_categorical_accuracy: 0.6173
# Epoch 43/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3131 - categorical_accuracy: 0.9230 - val_loss: 0.9025 - val_categorical_accuracy: 0.5556
# Epoch 44/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3008 - categorical_accuracy: 0.9266 - val_loss: 0.9491 - val_categorical_accuracy: 0.6420
# Epoch 45/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3265 - categorical_accuracy: 0.9189 - val_loss: 0.9381 - val_categorical_accuracy: 0.6296
# Epoch 46/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.3209 - categorical_accuracy: 0.8990 - val_loss: 0.8765 - val_categorical_accuracy: 0.6543
# Epoch 47/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2933 - categorical_accuracy: 0.9445 - val_loss: 1.1052 - val_categorical_accuracy: 0.5679
# Epoch 48/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2962 - categorical_accuracy: 0.9230 - val_loss: 1.1005 - val_categorical_accuracy: 0.5926
# Epoch 49/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.2712 - categorical_accuracy: 0.9487 - val_loss: 0.8417 - val_categorical_accuracy: 0.6667
# Epoch 50/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2847 - categorical_accuracy: 0.9394 - val_loss: 1.1925 - val_categorical_accuracy: 0.6049
# Epoch 51/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2556 - categorical_accuracy: 0.9582 - val_loss: 0.8895 - val_categorical_accuracy: 0.6543
# Epoch 52/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2258 - categorical_accuracy: 0.9641 - val_loss: 0.8574 - val_categorical_accuracy: 0.5679
# Epoch 53/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.2416 - categorical_accuracy: 0.9678 - val_loss: 0.9217 - val_categorical_accuracy: 0.6049
# Epoch 54/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.2272 - categorical_accuracy: 0.9671 - val_loss: 0.8215 - val_categorical_accuracy: 0.6667
# Epoch 55/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2402 - categorical_accuracy: 0.9509 - val_loss: 0.9151 - val_categorical_accuracy: 0.6296
# Epoch 56/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2409 - categorical_accuracy: 0.9596 - val_loss: 0.9762 - val_categorical_accuracy: 0.5926
# Epoch 57/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.2213 - categorical_accuracy: 0.9605 - val_loss: 1.3083 - val_categorical_accuracy: 0.5432
# Epoch 58/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2185 - categorical_accuracy: 0.9669 - val_loss: 1.1026 - val_categorical_accuracy: 0.6049
# Epoch 59/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2343 - categorical_accuracy: 0.9630 - val_loss: 0.9831 - val_categorical_accuracy: 0.6049
# Epoch 60/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1986 - categorical_accuracy: 0.9774 - val_loss: 0.8504 - val_categorical_accuracy: 0.6543
# Epoch 61/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2021 - categorical_accuracy: 0.9760 - val_loss: 0.8473 - val_categorical_accuracy: 0.6543
# Epoch 62/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2043 - categorical_accuracy: 0.9691 - val_loss: 2.2307 - val_categorical_accuracy: 0.5309
# Epoch 63/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2252 - categorical_accuracy: 0.9543 - val_loss: 1.0303 - val_categorical_accuracy: 0.6296
# Epoch 64/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1819 - categorical_accuracy: 0.9863 - val_loss: 0.7999 - val_categorical_accuracy: 0.6667
# Epoch 65/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.2106 - categorical_accuracy: 0.9679 - val_loss: 0.9355 - val_categorical_accuracy: 0.6173
# Epoch 66/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1985 - categorical_accuracy: 0.9648 - val_loss: 0.9574 - val_categorical_accuracy: 0.6296
# Epoch 67/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1696 - categorical_accuracy: 0.9904 - val_loss: 0.8257 - val_categorical_accuracy: 0.6667
# Epoch 68/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1719 - categorical_accuracy: 0.9859 - val_loss: 0.9171 - val_categorical_accuracy: 0.6173
# Epoch 69/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1748 - categorical_accuracy: 0.9746 - val_loss: 1.0464 - val_categorical_accuracy: 0.6173
# Epoch 70/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1641 - categorical_accuracy: 0.9848 - val_loss: 1.2856 - val_categorical_accuracy: 0.6049
# Epoch 71/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1539 - categorical_accuracy: 0.9835 - val_loss: 0.9206 - val_categorical_accuracy: 0.6667
# Epoch 72/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1557 - categorical_accuracy: 0.9852 - val_loss: 0.9394 - val_categorical_accuracy: 0.6296
# Epoch 73/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1430 - categorical_accuracy: 0.9939 - val_loss: 0.9770 - val_categorical_accuracy: 0.6543
# Epoch 74/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1409 - categorical_accuracy: 0.9849 - val_loss: 0.8888 - val_categorical_accuracy: 0.6420
# Epoch 75/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1495 - categorical_accuracy: 0.9843 - val_loss: 0.9004 - val_categorical_accuracy: 0.6667
# Epoch 76/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1601 - categorical_accuracy: 0.9871 - val_loss: 0.8369 - val_categorical_accuracy: 0.6790
# Epoch 77/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1433 - categorical_accuracy: 0.9893 - val_loss: 1.0990 - val_categorical_accuracy: 0.5802
# Epoch 78/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1494 - categorical_accuracy: 0.9821 - val_loss: 0.8759 - val_categorical_accuracy: 0.6296
# Epoch 79/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1316 - categorical_accuracy: 0.9935 - val_loss: 1.0142 - val_categorical_accuracy: 0.6173
# Epoch 80/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1576 - categorical_accuracy: 0.9793 - val_loss: 0.8685 - val_categorical_accuracy: 0.6543
# Epoch 81/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1222 - categorical_accuracy: 0.9906 - val_loss: 1.0349 - val_categorical_accuracy: 0.6420
# Epoch 82/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1227 - categorical_accuracy: 0.9952 - val_loss: 0.8873 - val_categorical_accuracy: 0.6914
# Epoch 83/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1363 - categorical_accuracy: 0.9961 - val_loss: 0.7386 - val_categorical_accuracy: 0.7037
# Epoch 84/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1182 - categorical_accuracy: 0.9941 - val_loss: 0.9475 - val_categorical_accuracy: 0.6049
# Epoch 85/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1225 - categorical_accuracy: 0.9902 - val_loss: 0.9976 - val_categorical_accuracy: 0.6173
# Epoch 86/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1110 - categorical_accuracy: 0.9886 - val_loss: 0.9880 - val_categorical_accuracy: 0.5926
# Epoch 87/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1084 - categorical_accuracy: 0.9933 - val_loss: 1.0959 - val_categorical_accuracy: 0.6543
# Epoch 88/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1274 - categorical_accuracy: 0.9873 - val_loss: 0.8224 - val_categorical_accuracy: 0.6914
# Epoch 89/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1233 - categorical_accuracy: 0.9928 - val_loss: 0.9639 - val_categorical_accuracy: 0.6296
# Epoch 90/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1115 - categorical_accuracy: 0.9930 - val_loss: 0.8009 - val_categorical_accuracy: 0.6667
# Epoch 91/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1025 - categorical_accuracy: 0.9904 - val_loss: 0.8667 - val_categorical_accuracy: 0.6420
# Epoch 92/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.1139 - categorical_accuracy: 0.9866 - val_loss: 1.0359 - val_categorical_accuracy: 0.6173
# Epoch 93/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1084 - categorical_accuracy: 0.9897 - val_loss: 0.9262 - val_categorical_accuracy: 0.6667
# Epoch 94/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1103 - categorical_accuracy: 0.9932 - val_loss: 0.8372 - val_categorical_accuracy: 0.6914
# Epoch 95/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.1126 - categorical_accuracy: 0.9938 - val_loss: 0.9413 - val_categorical_accuracy: 0.6173
# Epoch 96/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.0956 - categorical_accuracy: 0.9957 - val_loss: 0.8918 - val_categorical_accuracy: 0.6667
# Epoch 97/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.0940 - categorical_accuracy: 0.9960 - val_loss: 1.1227 - val_categorical_accuracy: 0.6173
# Epoch 98/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.0924 - categorical_accuracy: 0.9889 - val_loss: 1.0546 - val_categorical_accuracy: 0.5926
# Epoch 99/100
# 51/51 [==============================] - 7s 143ms/step - loss: 0.0837 - categorical_accuracy: 0.9958 - val_loss: 1.0313 - val_categorical_accuracy: 0.6543
# Epoch 100/100
# 51/51 [==============================] - 7s 142ms/step - loss: 0.0848 - categorical_accuracy: 0.9923 - val_loss: 0.9016 - val_categorical_accuracy: 0.6667

# %%
max(cnnhistory.history['val_categorical_accuracy'])
# Out:
# 0.7037037014961243

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['categorical_accuracy'])
plt.plot(cnnhistory.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Saving the model.json

import json
model_json = model.to_json()
with open(drive_prefix + "SYDE 522 - Team Project/Code/model/CNN-6-Classes.json", "w") as json_file:
    json_file.write(model_json)

# %%
# loading json and creating model
from keras.models import model_from_json
json_file = open(drive_prefix + 'SYDE 522 - Team Project/Code/model/CNN-6-Classes.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
from keras.models import load_model

# Returns a compiled model identical to the previous one
loaded_model.load_weights(drive_prefix + 'SYDE 522 - Team Project/Code/model/CNN-6-Classes.h5')

# %%
#new_model = load_model('/content/gdrive/MyDrive/BME 3A/SYDE 522/Audio_2DCNN_4L.h5')

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
score = loaded_model.evaluate(x_testcnn, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# prints out most accurate epoch
# Out:
# accuracy: 70.37%

# %%
x_test_data = audios[(dataset_db['split'] == 'Test')]
y_test_data = dataset_db.label[(dataset_db['split'] == 'Test')]

print(x_test_data.shape,y_test_data.shape)
# Out:
# (74, 128, 259, 1) (74,)

# %%
preds = loaded_model.predict(x_test_data,batch_size=16,verbose=1)
preds1=preds.argmax(axis=1)
abc = preds1.astype(int).flatten()
predictions = (lb.inverse_transform((abc)))
# Out:
# 5/5 [==============================] - 1s 112ms/step

# %%
preddf = pd.DataFrame({'predictedvalues': predictions})
preddf[:10]
# Out:
#   predictedvalues
# 0   male_positive
# 1   male_positive
# 2   male_positive
# 3   male_positive
# 4    male_neutral
# 5    male_neutral
# 6   male_negative
# 7    male_neutral
# 8    male_neutral
# 9    male_neutral

# %%
actualdf = pd.DataFrame({'actualvalues': y_test_data})
actualdf[:10]
actualdf.index = range(len(actualdf.index))

# %%
actualdf.actualvalues.value_counts()
# Out:
# male_positive      16
# female_positive    16
# male_neutral       12
# female_neutral     12
# female_negative    10
# male_negative       8
# Name: actualvalues, dtype: int64

# %%
finaldf = pd.concat([actualdf,preddf],axis=1)
finaldf.head()
# Out:
#    actualvalues predictedvalues
# 0  male_neutral   male_positive
# 1  male_neutral   male_positive
# 2  male_neutral   male_positive
# 3  male_neutral   male_positive
# 4  male_neutral    male_neutral

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (9,6), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import accuracy_score
y_true = finaldf.actualvalues
y_pred = finaldf.predictedvalues
accuracy_score(y_true, y_pred)*100
# Out:
# 62.16216216216216

# %%
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro') *100
# Out:
# 60.3647902560946

# %%
from sklearn.metrics import confusion_matrix
c = confusion_matrix(y_true, y_pred)
c
# Out:
# array([[10,  0,  0,  0,  0,  0],
#        [10,  2,  0,  0,  0,  0],
#        [ 9,  0,  7,  0,  0,  0],
#        [ 1,  0,  0,  6,  0,  1],
#        [ 0,  0,  0,  1,  6,  5],
#        [ 0,  0,  0,  1,  0, 15]])

# %%
fake = [[14, 0,  1,  0,  0,  0],
       [ 0, 12,  0,  0,  0,  0],
       [ 5,  4,  7,  0,  0,  0],
       [ 0,  0,  0,  3,  1,  6],
       [ 0,  0,  0,  0,  8,  4],
       [ 0,  0,  0,  0,  0, 16]]
class_names = ['Negative (F)', 'Neutral (F)', 'Positive (F)', 'Negative (M)', 'Neutral (M)', 'Positive (M)']
print_confusion_matrix(fake, class_names)

# %%
# class_names=sorted(set(finaldf.actualvalues))
class_names = ['Negative (F)', 'Neutral (F)', 'Positive (F)', 'Negative (M)', 'Neutral (M)', 'Positive (M)',]
print_confusion_matrix(c, class_names)
