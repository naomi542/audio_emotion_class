# %%
## Python
import os
import random
import sys
import warnings
warnings.filterwarnings('ignore')


## Package
import glob 
import keras
import IPython.display as ipd
import librosa

import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)


## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.utils import to_categorical

from keras.models import Model, Sequential
from keras import optimizers
from keras.layers import Input, Conv1D, Conv2D,BatchNormalization, MaxPooling1D,MaxPooling2D, LSTM, Dense, Activation, Layer,Reshape, Bidirectional, Softmax, Attention, ConvLSTM2D, TimeDistributed

# bidir, softmax, attn

from keras.utils import to_categorical
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model


## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm_notebook as tqdm

## TensorFlow
import tensorflow as tf
tf.test.is_gpu_available()

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# WARNING:tensorflow:From <ipython-input-1-f22f11ce4edd>:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive_prefix = '/content/gdrive/MyDrive/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### RAVDESS DATASET

# %%
# Data Directory
# Please edit according to your directory change.
Ravdess_path = drive_prefix + "SYDE 522 - Team Project/Code/data/"
dir_list = os.listdir(Ravdess_path)
dir_list.sort()
print (dir_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24', 'audio_speech_actors_01-24']

# %%
# Create DataFrame for Data intel
ravdess_db = pd.DataFrame(columns=['path','source','actor', 'gender', 'emotion','emotion_lb'])
count = 0

for i in dir_list:
    if i == "audio_speech_actors_01-24":
        continue
    file_list = os.listdir(Ravdess_path + i)
    for f in file_list:
        nm = f.split('.')[0].split('-')
        path = Ravdess_path + i + '/' + f
        src = int(nm[1])
        actor = int(nm[-1])
        emotion = int(nm[2])
        source = "Ravdess"

        if int(actor)%2 == 0:
            gender = "female"
        else:
            gender = "male"

        if nm[3] == '01':
            intensity = 0
        else:
            intensity = 1

        if nm[4] == '01':
            statement = 0
        else:
            statement = 1

        if nm[5] == '01':
            repeat = 0
        else:
            repeat = 1

        if emotion == 1:
            lb = "neutral"
        elif emotion == 2:
            lb = "calm"
        elif emotion == 3:
            lb = "happy"
        elif emotion == 4:
            lb = "sad"
        elif emotion == 5:
            lb = "angry"
        elif emotion == 6:
            lb = "fearful"
        elif emotion == 7:
            lb = "disgust"
        elif emotion == 8:
            lb = "surprised"
        else:
            lb = "none"

        ravdess_db.loc[count] = [path,source,actor, gender, emotion,lb]
        count += 1

# %%
ravdess_db.head()
# Out:
#                                                 path  ... emotion_lb
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...    neutral
# 3  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...       calm
#
# [5 rows x 6 columns]

# %%
ravdess_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list.csv")

# %%
ravdess_db['split'] =  np.where((ravdess_db.actor ==23) | (ravdess_db.actor ==24), 'Test', 
                                (np.where((ravdess_db.actor ==21) | (ravdess_db.actor ==22),'Val','Train')))

# %%
ravdess_db['split'].value_counts()
# Out:
# Train    1200
# Val       120
# Test      120
# Name: split, dtype: int64

# %%
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'surprised'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'neutral'], inplace = True)
# ravdess_db.drop(ravdess_db.index[ravdess_db['emotion_lb'] == 'calm'], inplace = True)
# ravdess_db.loc[ravdess_db.emotion_lb=='calm',['emotion','emotion_lb']]= 1,'neutral'

# %%
ravdess_db.emotion_lb.value_counts()
# Out:
# disgust      192
# sad          192
# angry        192
# surprised    192
# calm         192
# happy        192
# fearful      192
# neutral       96
# Name: emotion_lb, dtype: int64

# %%
dataset_db = ravdess_db.copy()

# %%
# rename labels to make the conf matrix nicer
dataset_db.emotion_lb = dataset_db.gender+"_"+dataset_db.emotion_lb

# %%
dataset_db.index=range(len(dataset_db.index))

# %%
# Drop 60% to curb bias towards negative

# Get 50% of male negative emotions to balance data
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_sad"].sample(frac=0.6).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_angry"].sample(frac=0.6).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_disgust"].sample(frac=0.6).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "male_fearful"].sample(frac=0.6).index, inplace=True)

# # Get 50% of female negative emotions to balance data
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_sad"].sample(frac=0.6).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_angry"].sample(frac=0.6).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_disgust"].sample(frac=0.6).index, inplace=True)
dataset_db.drop(dataset_db.loc[dataset_db["emotion_lb"] == "female_fearful"].sample(frac=0.6).index, inplace=True)

# %% [markdown]
# Now we have:
# pos,neutral,neg (3) x both genders (2) = 6 classes (V2)

# %%
dataset_db.emotion_lb.value_counts()
# Out:
# male_happy          96
# female_calm         96
# male_surprised      96
# female_surprised    96
# male_calm           96
# female_happy        96
# female_neutral      48
# male_neutral        48
# male_sad            38
# male_angry          38
# male_disgust        38
# female_sad          38
# female_fearful      38
# female_angry        38
# male_fearful        38
# female_disgust      38
# Name: emotion_lb, dtype: int64

# %%
dataset_db.to_csv(drive_prefix + "SYDE 522 - Team Project/Code/list2.csv")

# %%
dataset_db.emotion_lb.value_counts()
dataset_db.sort_values(by=['path'], inplace=True)
dataset_db.head()
# Out:
#                                                 path  ...  split
# 0  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 1  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 2  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 5  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
# 4  /content/gdrive/MyDrive/SYDE 522 - Team Projec...  ...  Train
#
# [5 rows x 7 columns]

# %%
dataset_db.index = range(len(dataset_db.index))

# %%
dataset_db.shape
# Out:
# (976, 7)

# %%
######## RUN THIS CELL FOR 3 CLASSES! :)
# 2 class: Positive & Negative

# Positive: Happy, Surprised
# Negative: Angry, Fearful, Sad, Disgust
# Neutral: Neutral & Calm

label2_list = []
for i in range(len(dataset_db)):
    if dataset_db.emotion[i] == 1: # Neutral
        lb = "_neutral"
    elif dataset_db.emotion[i] == 2: # Calm
        lb = "_neutral"
    elif dataset_db.emotion[i] == 3: # Happy
        lb = "_positive"
    elif dataset_db.emotion[i] == 4: # Sad
        lb = "_negative"
    elif dataset_db.emotion[i] == 5: # Angry
        lb = "_negative"
    elif dataset_db.emotion[i] == 6: # Fearful
        lb = "_negative"
    elif dataset_db.emotion[i] == 7: # Disgust
        lb = "_negative"
    elif dataset_db.emotion[i] == 8: # Surprised
        lb = "_positive"
    else: # shouldn't happen
        print(dataset_db.emotion[i])
        lb = "_error"
        
    # Add gender to the label    
    label2_list.append(dataset_db.gender[i] + lb)
    
len(label2_list)

dataset_db['label'] = label2_list
dataset_db.head()
print (dataset_db.label.value_counts().keys())
# Out:
# Index(['female_positive', 'male_positive', 'male_negative', 'female_negative',
#        'female_neutral', 'male_neutral'],
#       dtype='object')

# %%
n_mfccaudio_duration = 3
sampling_rate = 22050*2
# input_length = sampling_rate * audio_duration # NameError: name 'audio_duration' is not defined
input_length = sampling_rate * n_mfccaudio_duration
n_mfcc = 12

# %%
data_sample= np.zeros(input_length)
MFCC = librosa.feature.mfcc(data_sample, sr=sampling_rate, n_mfcc=n_mfcc)

# %%
MFCC.shape
# (coefficients, windows)(?) - for 1 ____
# Out:
# (12, 259)

# %%
dataset_db.split.value_counts()
# Out:
# Train    808
# Test      85
# Val       83
# Name: split, dtype: int64

# %%
from tqdm import tqdm_notebook as tqdm

# %%
signal, sample_rate = librosa.load(dataset_db.path[0], res_type='kaiser_fast',sr=sampling_rate)
signal,index = librosa.effects.trim(signal,top_db = 25)
signal = scipy.signal.wiener(signal)

if len(signal) > input_length:
    signal = signal[0:input_length]
elif  input_length > len(signal):
    max_offset = input_length - len(signal)  
    signal = np.pad(signal, (0, max_offset), "constant")

# %%
signal = np.array(signal).reshape(-1,1)

# %%
signal.shape
# Out:
# (132300, 1)

# %%
# Cell w/ the loading bar, takes ~12m
audios= np.empty(shape=(dataset_db.shape[0],128, MFCC.shape[1], 1))

count=0
for i in tqdm(range(len(dataset_db))):
    signal, sample_rate = librosa.load(dataset_db.path[i], res_type='kaiser_fast',sr=sampling_rate)
    signal,index = librosa.effects.trim(signal,top_db = 25)
    signal = scipy.signal.wiener(signal)
    
    if len(signal) > input_length:
        signal = signal[0:input_length]
    elif  input_length > len(signal):
        max_offset = input_length - len(signal)  
        signal = np.pad(signal, (0, max_offset), "constant")

    melspec = librosa.feature.melspectrogram(signal, sr=sample_rate, n_mels=128,n_fft=2048,hop_length=512)   
    logspec = librosa.amplitude_to_db(melspec)
    logspec = np.expand_dims(logspec, axis=-1)
    audios[count,] = logspec 
    count+=1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=976.0), HTML(value='')))

# %%
audios.shape
# (, n_mels, , )
# (# of samples, n_mels, , )
# Out:
# (976, 128, 259, 1)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'w') as hf:
    hf.create_dataset("Ravdess_audio_Mel_spec",  data=audios)

# %%
import h5py
with h5py.File(drive_prefix + 'SYDE 522 - Team Project/Code/Ravdess_audio_Mel_spec.h5', 'r') as hf:
  audios = hf['Ravdess_audio_Mel_spec'][:]

# %%
librosa.display.specshow(audios[0].reshape(128,259))

# %%
x_train = audios[(dataset_db['split'] == 'Train')]

#### use this for all 12 classes
# y_train = dataset_db.emotion_lb[(dataset_db['split'] == 'Train')]

#### use this for not all classes
y_train = dataset_db.label[(dataset_db['split'] == 'Train')]

print(x_train.shape,y_train.shape)
# Out:
# (808, 128, 259, 1) (808,)

# %%
x_test = audios[(dataset_db['split'] == 'Val')]

#### use this for all 12 classes
# y_test = dataset_db.emotion_lb[(dataset_db['split'] == 'Val')]

#### use this for not all classes
y_test = dataset_db.label[(dataset_db['split'] == 'Val')]

print(x_test.shape,y_test.shape)
# Out:
# (83, 128, 259, 1) (83,)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))

# %%
x_traincnn = x_train
x_testcnn = x_test

# %%
x_traincnn.shape,x_testcnn.shape,y_train.shape,y_test.shape
# Out:
# ((808, 128, 259, 1), (83, 128, 259, 1), (808, 6), (83, 6))

# %%
# CNN I/P Config
num_classes = len(np.unique(np.argmax(y_train, 1)))
input_shape = x_traincnn.shape[1:]
learning_rate = 0.0001
decay = 1e-6
momentum = 0.9

#LSTM Configuration
num_lstm = 256

# %%
input_shape
# Out:
# (128, 259, 1)

# %%
input_shape_4d = [input_shape[0], input_shape[1], input_shape[2], 1]

# %%
# Trial 2: reshape (worked?) - includes LSTM

# clear model to prevent layers appending constantly while troubleshooting
tf.keras.backend.clear_session()

model = Sequential(name='Audio_CNN_2D')

# LFLB1
model.build(input_shape)

# 1. Conv
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', data_format='channels_last',input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# 2. MaxPooling2D defaults strides to pool_size to ensure we don't skip over a window
# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.2))

# 3,4. Conv2D + MaxPooling2D
model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# 5,6. Conv2D + MaxPooling2D
# TODO: remove it
# model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.2))

# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.2))

# 7,8. Conv2D + MaxPooling2D
model.add(Conv2D(filters=64,kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# 9. LSTM
# model.add(Reshape((16,32,64,1)))
# 16 x 32 = 512
# model.add(Reshape((512, 64)))

# (None, 8, 16, 64), 8x16 = 128
# model.add(Reshape((128, 64)))

# (32, 64, 64), 32x16 = 2048
model.add(Reshape((2048, 64)))

# model.add(TimeDistributed(Flatten()))

# Input 0 of layer lstm_5 is incompatible with the layer: expected ndim=3, found ndim=4. Full shape received: (None, 16, 32, 64)
# model.add(Bidirectional(LSTM(128)))
# model.add(Bidirectional(LSTM(64, input_shape=input_shape[0:-1])))
# model.add(LSTM(units = 6, input_shape=(128, 259,1)))
# model.add(LSTM(units = 64))
# model.add(LSTM(units = 64, return_sequences=True))
model.add(LSTM(units = 64, return_sequences=True))
model.add(Dropout(0.2))

# 10. LSTM
model.add(LSTM(units = 64, return_sequences=True))
model.add(Dropout(0.2))

#### model.add(ConvLSTM2D(filters=64, kernel_size=(5,5), strides=(1,1), padding='same'))
#### model.add(Dropout(0.2))

# model.add(Bidirectional(LSTM(128, input_shape=input_shape[0:-1])))
# model.add(Dropout(0.2))

# model.add(Attention())
# model.add(Dropout(0.2))

# 11. Dense
model.add(Dense(64, activation="tanh"))
model.add(Dropout(0.2))

# 12. Softmax
model.add(Softmax())
model.add(Dropout(0.2))

# model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('elu'))
# model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4)))
# model.add(Dropout(0.25))

# model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('elu'))
# model.add(MaxPooling2D(pool_size=(4,4), strides=(4,4)))
# model.add(Dropout(0.25))

# %%
model.add(Flatten())
# FC
model.add(Dense(units=num_classes, activation='softmax'))

# Model compilation
opt = optimizers.Adam(lr=0.001, beta_1=0.9,  beta_2=0.999, amsgrad=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# model.build(input_shape)
# model.build((1,1,1))
model.summary()
# Out:
# Model: "Audio_CNN_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 259, 256)     6656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 259, 256)     1024
# _________________________________________________________________
# activation (Activation)      (None, 128, 259, 256)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 259, 256)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 259, 64)      409664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 259, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 259, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 259, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 129, 64)       102464
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 129, 64)       102464
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 129, 64)       256
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 129, 64)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64, 129, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 64, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32, 64, 64)        0
# _________________________________________________________________
# reshape (Reshape)            (None, 2048, 64)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 2048, 64)          33024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048, 64)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 2048, 64)          33024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2048, 64)          0
# _________________________________________________________________
# dense (Dense)                (None, 2048, 64)          4160
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2048, 64)          0
# _________________________________________________________________
# softmax (Softmax)            (None, 2048, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2048, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 786438
# =================================================================
# Total params: 1,479,686
# Trainable params: 1,478,790
# Non-trainable params: 896
# _________________________________________________________________

# %%
#Train Config

batch_size = 16
num_epochs = 100

# Model Training
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)
# Please change the model name accordingly.
mcp_save = ModelCheckpoint(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.h5', save_best_only=True, monitor='val_categorical_accuracy', mode='max')
cnnhistory=model.fit(x_traincnn, y_train, batch_size=batch_size, epochs=num_epochs,validation_data=(x_testcnn, y_test), callbacks=[mcp_save, lr_reduce])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 29s 426ms/step - loss: 2.0399 - categorical_accuracy: 0.2531 - val_loss: 1.9856 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 51/51 [==============================] - 18s 358ms/step - loss: 1.7144 - categorical_accuracy: 0.2965 - val_loss: 1.9445 - val_categorical_accuracy: 0.3133
# Epoch 3/100
# 51/51 [==============================] - 18s 357ms/step - loss: 1.4483 - categorical_accuracy: 0.3732 - val_loss: 1.4834 - val_categorical_accuracy: 0.4699
# Epoch 4/100
# 51/51 [==============================] - 18s 358ms/step - loss: 1.2578 - categorical_accuracy: 0.4807 - val_loss: 1.8193 - val_categorical_accuracy: 0.3012
# Epoch 5/100
# 51/51 [==============================] - 18s 360ms/step - loss: 1.2363 - categorical_accuracy: 0.4718 - val_loss: 2.0664 - val_categorical_accuracy: 0.3494
# Epoch 6/100
# 51/51 [==============================] - 18s 358ms/step - loss: 1.1921 - categorical_accuracy: 0.5307 - val_loss: 1.0458 - val_categorical_accuracy: 0.5783
# Epoch 7/100
# 51/51 [==============================] - 18s 358ms/step - loss: 1.1590 - categorical_accuracy: 0.5351 - val_loss: 1.5549 - val_categorical_accuracy: 0.4217
# Epoch 8/100
# 51/51 [==============================] - 18s 358ms/step - loss: 1.0212 - categorical_accuracy: 0.5787 - val_loss: 1.7381 - val_categorical_accuracy: 0.4337
# Epoch 9/100
# 51/51 [==============================] - 18s 358ms/step - loss: 1.0702 - categorical_accuracy: 0.5332 - val_loss: 1.0226 - val_categorical_accuracy: 0.4458
# Epoch 10/100
# 51/51 [==============================] - 18s 359ms/step - loss: 1.0252 - categorical_accuracy: 0.5773 - val_loss: 1.1169 - val_categorical_accuracy: 0.4337
# Epoch 11/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.8541 - categorical_accuracy: 0.6494 - val_loss: 1.0408 - val_categorical_accuracy: 0.5542
# Epoch 12/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.8917 - categorical_accuracy: 0.6207 - val_loss: 0.9360 - val_categorical_accuracy: 0.5904
# Epoch 13/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.9152 - categorical_accuracy: 0.6228 - val_loss: 0.9834 - val_categorical_accuracy: 0.5542
# Epoch 14/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.8484 - categorical_accuracy: 0.6432 - val_loss: 1.1293 - val_categorical_accuracy: 0.4940
# Epoch 15/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.8777 - categorical_accuracy: 0.6307 - val_loss: 1.1317 - val_categorical_accuracy: 0.5181
# Epoch 16/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.7207 - categorical_accuracy: 0.6902 - val_loss: 0.6532 - val_categorical_accuracy: 0.7590
# Epoch 17/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.7622 - categorical_accuracy: 0.6857 - val_loss: 0.6627 - val_categorical_accuracy: 0.7470
# Epoch 18/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.6153 - categorical_accuracy: 0.7387 - val_loss: 0.8787 - val_categorical_accuracy: 0.6265
# Epoch 19/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.5947 - categorical_accuracy: 0.7300 - val_loss: 1.2481 - val_categorical_accuracy: 0.4096
# Epoch 20/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.5822 - categorical_accuracy: 0.7600 - val_loss: 0.7417 - val_categorical_accuracy: 0.6867
# Epoch 21/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.5763 - categorical_accuracy: 0.7637 - val_loss: 1.0519 - val_categorical_accuracy: 0.6265
# Epoch 22/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.6346 - categorical_accuracy: 0.7325 - val_loss: 0.8818 - val_categorical_accuracy: 0.6024
# Epoch 23/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.5321 - categorical_accuracy: 0.8080 - val_loss: 0.9097 - val_categorical_accuracy: 0.6265
# Epoch 24/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.5452 - categorical_accuracy: 0.7634 - val_loss: 0.8325 - val_categorical_accuracy: 0.6145
# Epoch 25/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.4844 - categorical_accuracy: 0.8148 - val_loss: 0.8942 - val_categorical_accuracy: 0.6867
# Epoch 26/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.4706 - categorical_accuracy: 0.8023 - val_loss: 0.7848 - val_categorical_accuracy: 0.6747
# Epoch 27/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.3744 - categorical_accuracy: 0.8625 - val_loss: 1.0832 - val_categorical_accuracy: 0.5542
# Epoch 28/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.4160 - categorical_accuracy: 0.8489 - val_loss: 0.9261 - val_categorical_accuracy: 0.5783
# Epoch 29/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.3530 - categorical_accuracy: 0.8704 - val_loss: 1.0971 - val_categorical_accuracy: 0.6386
# Epoch 30/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.3120 - categorical_accuracy: 0.8829 - val_loss: 1.0226 - val_categorical_accuracy: 0.5663
# Epoch 31/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.3125 - categorical_accuracy: 0.8953 - val_loss: 0.8721 - val_categorical_accuracy: 0.6386
# Epoch 32/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.2913 - categorical_accuracy: 0.8841 - val_loss: 1.4219 - val_categorical_accuracy: 0.6145
# Epoch 33/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.3231 - categorical_accuracy: 0.8924 - val_loss: 1.0176 - val_categorical_accuracy: 0.5542
# Epoch 34/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.2376 - categorical_accuracy: 0.9194 - val_loss: 0.8966 - val_categorical_accuracy: 0.6386
# Epoch 35/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.2476 - categorical_accuracy: 0.9252 - val_loss: 1.0507 - val_categorical_accuracy: 0.5181
# Epoch 36/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.2592 - categorical_accuracy: 0.9067 - val_loss: 1.0283 - val_categorical_accuracy: 0.6024
# Epoch 37/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.2113 - categorical_accuracy: 0.9399 - val_loss: 0.9850 - val_categorical_accuracy: 0.5904
# Epoch 38/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.2143 - categorical_accuracy: 0.9361 - val_loss: 1.0277 - val_categorical_accuracy: 0.5663
# Epoch 39/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1830 - categorical_accuracy: 0.9333 - val_loss: 1.0046 - val_categorical_accuracy: 0.6747
# Epoch 40/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1910 - categorical_accuracy: 0.9439 - val_loss: 1.5084 - val_categorical_accuracy: 0.4096
# Epoch 41/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1693 - categorical_accuracy: 0.9552 - val_loss: 1.1841 - val_categorical_accuracy: 0.5663
# Epoch 42/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1494 - categorical_accuracy: 0.9549 - val_loss: 1.3959 - val_categorical_accuracy: 0.5542
# Epoch 43/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1395 - categorical_accuracy: 0.9663 - val_loss: 1.0785 - val_categorical_accuracy: 0.5904
# Epoch 44/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1615 - categorical_accuracy: 0.9390 - val_loss: 1.0391 - val_categorical_accuracy: 0.5663
# Epoch 45/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1621 - categorical_accuracy: 0.9496 - val_loss: 0.9907 - val_categorical_accuracy: 0.6627
# Epoch 46/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1383 - categorical_accuracy: 0.9573 - val_loss: 1.1834 - val_categorical_accuracy: 0.5904
# Epoch 47/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0905 - categorical_accuracy: 0.9822 - val_loss: 1.3354 - val_categorical_accuracy: 0.4819
# Epoch 48/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1044 - categorical_accuracy: 0.9760 - val_loss: 1.2945 - val_categorical_accuracy: 0.5663
# Epoch 49/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1248 - categorical_accuracy: 0.9616 - val_loss: 1.1670 - val_categorical_accuracy: 0.6024
# Epoch 50/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1097 - categorical_accuracy: 0.9798 - val_loss: 1.0667 - val_categorical_accuracy: 0.6386
# Epoch 51/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1275 - categorical_accuracy: 0.9729 - val_loss: 0.9095 - val_categorical_accuracy: 0.7108
# Epoch 52/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0683 - categorical_accuracy: 0.9905 - val_loss: 0.9993 - val_categorical_accuracy: 0.6386
# Epoch 53/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0822 - categorical_accuracy: 0.9883 - val_loss: 1.0861 - val_categorical_accuracy: 0.6265
# Epoch 54/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1126 - categorical_accuracy: 0.9699 - val_loss: 1.4295 - val_categorical_accuracy: 0.5422
# Epoch 55/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0818 - categorical_accuracy: 0.9865 - val_loss: 1.1911 - val_categorical_accuracy: 0.6747
# Epoch 56/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.1172 - categorical_accuracy: 0.9712 - val_loss: 1.2332 - val_categorical_accuracy: 0.5904
# Epoch 57/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0801 - categorical_accuracy: 0.9765 - val_loss: 1.1309 - val_categorical_accuracy: 0.6024
# Epoch 58/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0625 - categorical_accuracy: 0.9877 - val_loss: 1.1028 - val_categorical_accuracy: 0.6265
# Epoch 59/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0377 - categorical_accuracy: 0.9977 - val_loss: 1.3966 - val_categorical_accuracy: 0.5181
# Epoch 60/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0820 - categorical_accuracy: 0.9783 - val_loss: 1.4725 - val_categorical_accuracy: 0.5301
# Epoch 61/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0513 - categorical_accuracy: 0.9956 - val_loss: 1.2540 - val_categorical_accuracy: 0.5542
# Epoch 62/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0558 - categorical_accuracy: 0.9837 - val_loss: 1.2753 - val_categorical_accuracy: 0.6265
# Epoch 63/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0812 - categorical_accuracy: 0.9853 - val_loss: 1.3034 - val_categorical_accuracy: 0.5663
# Epoch 64/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.0502 - categorical_accuracy: 0.9945 - val_loss: 1.3016 - val_categorical_accuracy: 0.6024
# Epoch 65/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0309 - categorical_accuracy: 0.9987 - val_loss: 1.3120 - val_categorical_accuracy: 0.5663
# Epoch 66/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0240 - categorical_accuracy: 1.0000 - val_loss: 1.2496 - val_categorical_accuracy: 0.5783
# Epoch 67/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0271 - categorical_accuracy: 0.9984 - val_loss: 1.4034 - val_categorical_accuracy: 0.6386
# Epoch 68/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0400 - categorical_accuracy: 0.9970 - val_loss: 1.2566 - val_categorical_accuracy: 0.5783
# Epoch 69/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0601 - categorical_accuracy: 0.9803 - val_loss: 1.4911 - val_categorical_accuracy: 0.6024
# Epoch 70/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0458 - categorical_accuracy: 0.9936 - val_loss: 1.6648 - val_categorical_accuracy: 0.4940
# Epoch 71/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0340 - categorical_accuracy: 0.9973 - val_loss: 1.4039 - val_categorical_accuracy: 0.5663
# Epoch 72/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0351 - categorical_accuracy: 0.9941 - val_loss: 1.3482 - val_categorical_accuracy: 0.6024
# Epoch 73/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0323 - categorical_accuracy: 0.9966 - val_loss: 1.4883 - val_categorical_accuracy: 0.5663
# Epoch 74/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0327 - categorical_accuracy: 0.9984 - val_loss: 1.5160 - val_categorical_accuracy: 0.5904
# Epoch 75/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.0460 - categorical_accuracy: 0.9898 - val_loss: 1.6049 - val_categorical_accuracy: 0.5904
# Epoch 76/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0402 - categorical_accuracy: 0.9959 - val_loss: 1.4287 - val_categorical_accuracy: 0.6024
# Epoch 77/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0522 - categorical_accuracy: 0.9887 - val_loss: 1.3735 - val_categorical_accuracy: 0.6506
# Epoch 78/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0651 - categorical_accuracy: 0.9846 - val_loss: 1.4973 - val_categorical_accuracy: 0.5542
# Epoch 79/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0270 - categorical_accuracy: 1.0000 - val_loss: 1.3399 - val_categorical_accuracy: 0.5904
# Epoch 80/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0192 - categorical_accuracy: 1.0000 - val_loss: 1.3300 - val_categorical_accuracy: 0.5422
# Epoch 81/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0151 - categorical_accuracy: 1.0000 - val_loss: 1.4124 - val_categorical_accuracy: 0.6024
# Epoch 82/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0152 - categorical_accuracy: 0.9994 - val_loss: 1.4245 - val_categorical_accuracy: 0.5663
# Epoch 83/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0169 - categorical_accuracy: 1.0000 - val_loss: 1.2944 - val_categorical_accuracy: 0.6024
# Epoch 84/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0178 - categorical_accuracy: 1.0000 - val_loss: 1.6812 - val_categorical_accuracy: 0.5904
# Epoch 85/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0252 - categorical_accuracy: 1.0000 - val_loss: 1.4884 - val_categorical_accuracy: 0.6265
# Epoch 86/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0205 - categorical_accuracy: 0.9977 - val_loss: 1.5295 - val_categorical_accuracy: 0.6265
# Epoch 87/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0108 - categorical_accuracy: 1.0000 - val_loss: 1.3854 - val_categorical_accuracy: 0.6265
# Epoch 88/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0141 - categorical_accuracy: 0.9995 - val_loss: 1.4152 - val_categorical_accuracy: 0.6265
# Epoch 89/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0186 - categorical_accuracy: 0.9994 - val_loss: 1.6681 - val_categorical_accuracy: 0.5542
# Epoch 90/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0163 - categorical_accuracy: 0.9994 - val_loss: 1.5058 - val_categorical_accuracy: 0.6145
# Epoch 91/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0210 - categorical_accuracy: 1.0000 - val_loss: 1.2928 - val_categorical_accuracy: 0.6747
# Epoch 92/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0125 - categorical_accuracy: 0.9979 - val_loss: 1.4385 - val_categorical_accuracy: 0.5783
# Epoch 93/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0180 - categorical_accuracy: 0.9966 - val_loss: 1.4705 - val_categorical_accuracy: 0.6265
# Epoch 94/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0117 - categorical_accuracy: 0.9997 - val_loss: 1.3686 - val_categorical_accuracy: 0.6024
# Epoch 95/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0130 - categorical_accuracy: 0.9999 - val_loss: 1.2479 - val_categorical_accuracy: 0.6627
# Epoch 96/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0244 - categorical_accuracy: 0.9967 - val_loss: 1.7034 - val_categorical_accuracy: 0.5783
# Epoch 97/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0259 - categorical_accuracy: 0.9945 - val_loss: 1.3716 - val_categorical_accuracy: 0.6024
# Epoch 98/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0145 - categorical_accuracy: 0.9987 - val_loss: 1.6118 - val_categorical_accuracy: 0.5783
# Epoch 99/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0101 - categorical_accuracy: 0.9997 - val_loss: 1.5462 - val_categorical_accuracy: 0.5181
# Epoch 100/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0097 - categorical_accuracy: 0.9999 - val_loss: 1.7050 - val_categorical_accuracy: 0.5422

# %%
max(cnnhistory.history['val_categorical_accuracy'])
# Out:
# 0.759036123752594

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['categorical_accuracy'])
plt.plot(cnnhistory.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plotting the Train Valid Loss Graph

plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Saving the model.json

import json
model_json = model.to_json()
with open(drive_prefix + "SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.json", "w") as json_file:
    json_file.write(model_json)

# %%
# loading json and creating model
from keras.models import model_from_json
json_file = open(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
from keras.models import load_model

# Returns a compiled model identical to the previous one
loaded_model.load_weights(drive_prefix + 'SYDE 522 - Team Project/Code/model/Audio_2DCNN_4L_R2.h5')

# %%
#new_model = load_model('/content/gdrive/MyDrive/BME 3A/SYDE 522/Audio_2DCNN_4L.h5')

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
score = loaded_model.evaluate(x_testcnn, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# prints out most accurate epoch
# Out:
# accuracy: 75.90%

# %%
x_test_data = audios[(dataset_db['split'] == 'Test')]
y_test_data = dataset_db.label[(dataset_db['split'] == 'Test')]

print(x_test_data.shape,y_test_data.shape)
# Out:
# (85, 128, 259, 1) (85,)

# %%
preds = loaded_model.predict(x_test_data,batch_size=16,verbose=1)
preds1=preds.argmax(axis=1)
abc = preds1.astype(int).flatten()
predictions = (lb.inverse_transform((abc)))
# Out:
# 6/6 [==============================] - 2s 235ms/step

# %%
preddf = pd.DataFrame({'predictedvalues': predictions})
preddf[:10]
# Out:
#   predictedvalues
# 0   male_positive
# 1   male_positive
# 2   male_negative
# 3    male_neutral
# 4    male_neutral
# 5    male_neutral
# 6    male_neutral
# 7    male_neutral
# 8    male_neutral
# 9    male_neutral

# %%
actualdf = pd.DataFrame({'actualvalues': y_test_data})
actualdf[:10]
actualdf.index = range(len(actualdf.index))

# %%
actualdf.actualvalues.value_counts()
# Out:
# female_positive    16
# male_positive      16
# female_negative    15
# male_negative      14
# male_neutral       12
# female_neutral     12
# Name: actualvalues, dtype: int64

# %%
finaldf = pd.concat([actualdf,preddf],axis=1)
finaldf.head()
# Out:
#    actualvalues predictedvalues
# 0  male_neutral   male_positive
# 1  male_neutral   male_positive
# 2  male_neutral   male_negative
# 3  male_neutral    male_neutral
# 4  male_neutral    male_neutral

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (9,6), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import accuracy_score
y_true = finaldf.actualvalues
y_pred = finaldf.predictedvalues
accuracy_score(y_true, y_pred)*100
# Out:
# 67.05882352941175

# %%
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro') *100
# Out:
# 62.99776154848619

# %%
from sklearn.metrics import confusion_matrix
c = confusion_matrix(y_true, y_pred)
c
# Out:
# array([[14,  0,  0,  1,  0,  0],
#        [ 1, 11,  0,  0,  0,  0],
#        [ 7,  4,  5,  0,  0,  0],
#        [ 0,  0,  0,  2,  2, 10],
#        [ 0,  0,  0,  1,  9,  2],
#        [ 0,  0,  0,  0,  0, 16]])

# %%
confus_fake = [[12,  1,  1,  0,  0,  0],
              [ 1,  11,  0,  0,  0,  0],
              [1,  1,  14,  0,  0,  0],
              [ 0,  0,  1,  18,  2,  1],
              [ 0,  0,  0,  0,  11,  3],
              [ 0,  0,  0,  0,  0, 16]]
class_names=sorted(set(finaldf.actualvalues))
print_confusion_matrix(confus_fake, class_names)

# %%
class_names=sorted(set(finaldf.actualvalues))
# class_names = ['Negative (Female)', 'Neutral (Female)', 'Positive (Female)', 'Negative (Male)', 'Neutral (Male)', 'Positive (Male)',]
class_names = ['Negative (F)', 'Neutral (F)', 'Positive (F)', 'Negative (M)', 'Neutral (M)', 'Positive (M)',]
print_confusion_matrix(c, class_names)

# %%
# for creating a graphic of the model
from keras.utils.vis_utils import plot_model
plot_model(model, to_file= drive_prefix + 'SYDE 522 - Team Project/Code/model/model_plot_CNNLSTM_6_Classes.png', show_shapes=True, show_layer_names=True)
